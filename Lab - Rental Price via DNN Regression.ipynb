# %% [markdown]
# # Lab - Rental Price
# Reference: Dataset was extracted from one of the popular property listing site (updated to Sep 2018)
#
# Exercise:
# 1. Try train on all states dataset, then predict the rental based on selected features
# 2. Try train on only Selangor dataset, then predict the rental based on selected features

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import shutil

# %% [markdown]
# ## Read dataset

# %%
df_orig = pd.read_csv("./data/RentIndexRaw.csv", low_memory=False)
COLUMNS = list(df_orig)
print (COLUMNS)
# Out:
# ['ID', 'BuiltUpSize', 'City', 'CreatedDateTime', 'CreatedUser', 'DataSourceID', 'Furnishing', 'Latitude', 'Longitude', 'NoOfBathroom', 'NoOfBedroom', 'NoOfParking', 'Postcode', 'PostedDate', 'PropertyAddress', 'PropertyName', 'PropertyType', 'RentalPerMth', 'SourceUrl', 'State', 'UpdatedDateTime', 'UpdatedUser']

# %% [markdown]
# ## Preparing dataset

# %%
print('Original dataset: {}'.format(df_orig.shape))

df_orig['State'] = df_orig['State'].str.upper()
df_orig['City'] = df_orig['City'].str.upper()
df_orig['PropertyType'] = df_orig['PropertyType'].str.upper()

# Selangor
df_sel = df_orig[(df_orig.State == 'SELANGOR')]
print('Selangor dataset: {}'.format(df_sel.shape))

# KL
df_kul = df_orig[(df_orig.State == 'KUALA-LUMPUR')]
print('KL dataset: {}'.format(df_kul.shape))


# remove rows with zero value
df = df_sel[(df_sel[['BuiltUpSize','RentalPerMth', 'NoOfBedroom']] != 0).all(axis=1)]
                            #'NoOfBathroom', 'NoOfParking']] != 0).all(axis=1)]


print('Wanted dataset: {}'.format(df.shape))
# Out:
# Original dataset: (54405, 22)
# Selangor dataset: (30292, 22)
# KL dataset: (13648, 22)
# Wanted dataset: (20626, 22)

# %% [markdown]
# ## Split into dataset of: Train, Validation, Test (70%-20%-10%)

# %%
df_train0, df_valid0, df_test0 = np.split(df.sample(frac=1), [int(.7*len(df)), int(.9*len(df))])

# Retrieve only Featured columns
df_train = df_train0[['State','BuiltUpSize','RentalPerMth','NoOfBedroom','Furnishing','PropertyType']]
df_valid = df_valid0[['State','BuiltUpSize','RentalPerMth','NoOfBedroom','Furnishing','PropertyType']]
df_test = df_test0[['State','BuiltUpSize','RentalPerMth','NoOfBedroom','Furnishing','PropertyType']]

print('Train: {}'.format(df_train.shape))
print('Valid: {}'.format(df_valid.shape))
print('Test: {}'.format(df_test.shape))
# Out:
# Train: (14438, 6)
# Valid: (4125, 6)
# Test: (2063, 6)

# %% [markdown]
# ## Categorize string value columns

# %%
df_train['PropertyType'].unique()
# Out:
# array(['SERVICED RESIDENCE', 'CONDOMINIUM', 'APARTMENT',
#        '2-STY TERRACE/LINK HOUSE', 'SEMI-DETACHED HOUSE', 'FLAT',
#        '2.5-STY TERRACE/LINK HOUSE', '3-STY TERRACE/LINK HOUSE',
#        '1-STY TERRACE/LINK HOUSE', 'BUNGALOW', 'TOWNHOUSE',
#        '1.5-STY TERRACE/LINK HOUSE', 'CLUSTER HOUSE',
#        '3.5-STY TERRACE/LINK HOUSE', '4-STY TERRACE/LINK HOUSE'],
#       dtype=object)

# %%
df_train['State'].unique()
# Out:
# array(['SELANGOR'], dtype=object)

# %% [markdown]
# ## Determine metrics for validation - RMSE

# %%
def print_rmse(model, df):
  metrics = model.evaluate(input_fn = tf.estimator.inputs.pandas_input_fn(
    x = df,
    y = df[LABEL],
    batch_size = 128,
    shuffle = False,
    #queue_capacity = 100
      
  ))
  print('RMSE on dataset = {}'.format(np.sqrt(metrics['average_loss'])))
    
#print_rmse(model, df_valid)

# %% [markdown]
# ## Model: DNNRegressor

# %%
# DNNRegressor
LABEL = 'RentalPerMth'
OUTDIR = 'rentalDNNRegression_trained'
tf.logging.set_verbosity(tf.logging.INFO)
shutil.rmtree(OUTDIR, ignore_errors = True) # start fresh each time

# Categorize string features
categorical_column1 = tf.feature_column.categorical_column_with_vocabulary_list(
    key="State", vocabulary_list=['SELANGOR', 'JOHOR', 'KUALA-LUMPUR', 'PUTRAJAYA'], 
    default_value=0)

categorical_column2 = tf.feature_column.categorical_column_with_vocabulary_list(
    key="Furnishing", vocabulary_list=['Unfurnished', 'Fully Furnished', 'Partly Furnished', 'Unknown'], 
    default_value=0)

categorical_column3 = tf.feature_column.categorical_column_with_vocabulary_list(
    key="PropertyType", vocabulary_list=['CONDOMINIUM', 'SERVICED RESIDENCE', 'APARTMENT',
       '2-STY TERRACE/LINK HOUSE', '3-STY TERRACE/LINK HOUSE',
       '1-STY TERRACE/LINK HOUSE', 'TOWNHOUSE', 'SEMI-DETACHED HOUSE',
       'BUNGALOW', '1.5-STY TERRACE/LINK HOUSE',
       '3.5-STY TERRACE/LINK HOUSE', 'CLUSTER HOUSE', 'FLAT',
       '2.5-STY TERRACE/LINK HOUSE', '4-STY TERRACE/LINK HOUSE',
       'RESIDENTIAL LAND'], 
    default_value=0)


model = tf.estimator.DNNRegressor(    
    hidden_units = [64, 2048, 64],
    feature_columns = [tf.feature_column.numeric_column('BuiltUpSize'),
                       tf.feature_column.numeric_column('NoOfBedroom'),
                       #tf.feature_column.indicator_column(categorical_column1),
                       tf.feature_column.indicator_column(categorical_column2),
                       tf.feature_column.indicator_column(categorical_column3)
                      ], 
    activation_fn = tf.nn.relu,
    optimizer=tf.train.AdamOptimizer(
        learning_rate=0.001,
        #l1_regularization_strength=0.01
    ),

    model_dir = OUTDIR
)
 

model.train(input_fn = tf.estimator.inputs.pandas_input_fn(
    x = df_train,
    y = df_train[LABEL],
    batch_size = 128,
    num_epochs = 5,
    shuffle = True,
  ));

print_rmse(model, df_valid)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_num_ps_replicas': 0, '_master': '', '_keep_checkpoint_max': 5, '_save_checkpoints_steps': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0xb30ee2e10>, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_log_step_count_steps': 100, '_global_id_in_cluster': 0, '_device_fn': None, '_save_checkpoints_secs': 600, '_save_summary_steps': 100, '_model_dir': 'rentalDNNRegression_trained', '_session_config': None, '_num_worker_replicas': 1, '_task_type': 'worker', '_train_distribute': None, '_task_id': 0, '_is_chief': True, '_tf_random_seed': None, '_evaluation_master': ''}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into rentalDNNRegression_trained/model.ckpt.
# INFO:tensorflow:loss = 585207200.0, step = 1
# INFO:tensorflow:global_step/sec: 111.62
# INFO:tensorflow:loss = 178047460.0, step = 101 (0.897 sec)
# INFO:tensorflow:global_step/sec: 124.405
# INFO:tensorflow:loss = 120984136.0, step = 201 (0.804 sec)
# INFO:tensorflow:global_step/sec: 122.747
# INFO:tensorflow:loss = 235816400000.0, step = 301 (0.815 sec)
# INFO:tensorflow:global_step/sec: 124.619
# INFO:tensorflow:loss = 471709320000.0, step = 401 (0.803 sec)
# INFO:tensorflow:global_step/sec: 124.874
# INFO:tensorflow:loss = 181592640.0, step = 501 (0.800 sec)
# INFO:tensorflow:Saving checkpoints for 564 into rentalDNNRegression_trained/model.ckpt.
# INFO:tensorflow:Loss for final step: 671785500.0.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-08-13:59:33
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rentalDNNRegression_trained/model.ckpt-564
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-08-13:59:33
# INFO:tensorflow:Saving dict for global step 564: average_loss = 312130340.0, global_step = 564, label/mean = 2504.3457, loss = 39016292000.0, prediction/mean = 1869.226
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 564: rentalDNNRegression_trained/model.ckpt-564
# RMSE on dataset = 17667.2109375

# %% [markdown]
# ## Prediction

# %%
predictions = model.predict(input_fn = tf.estimator.inputs.pandas_input_fn(
#    x = pd.DataFrame({
#                      'BuiltUpSize':[560,1200,1600],
#                      'NoOfBedroom':[2,3,3],
#                      'PropertyType':['CONDOMINIUM', 'SERVICED RESIDENCE', 'APARTMENT'],
#                      'Furnishing':['Unfurnished', 'Fully Furnished', 'Partly Furnished']}),
    x = df_test,
    y = None,
    batch_size = 128,
    shuffle = False
  ))

for items in predictions:
  print(items)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rentalDNNRegression_trained/model.ckpt-564
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# {'predictions': array([1312.496], dtype=float32)}
# {'predictions': array([2350.7822], dtype=float32)}
# {'predictions': array([1934.3997], dtype=float32)}
# {'predictions': array([4282.42], dtype=float32)}
# {'predictions': array([2273.1992], dtype=float32)}
# {'predictions': array([3787.0547], dtype=float32)}
# {'predictions': array([3191.3438], dtype=float32)}
# {'predictions': array([1694.0834], dtype=float32)}
# {'predictions': array([1661.2302], dtype=float32)}
# {'predictions': array([3168.1958], dtype=float32)}
# {'predictions': array([2205.745], dtype=float32)}
# {'predictions': array([2648.3079], dtype=float32)}
# {'predictions': array([1336.4155], dtype=float32)}
# {'predictions': array([1615.724], dtype=float32)}
# {'predictions': array([734.3183], dtype=float32)}
# {'predictions': array([1533.6064], dtype=float32)}
# {'predictions': array([1466.1528], dtype=float32)}
# {'predictions': array([3456.3662], dtype=float32)}
# {'predictions': array([1793.2865], dtype=float32)}
# {'predictions': array([1982.9617], dtype=float32)}
# {'predictions': array([1459.4003], dtype=float32)}
# {'predictions': array([1767.7628], dtype=float32)}
# {'predictions': array([1735.7452], dtype=float32)}
# {'predictions': array([1417.7386], dtype=float32)}
# {'predictions': array([1352.4613], dtype=float32)}
# {'predictions': array([1414.0416], dtype=float32)}
# {'predictions': array([1620.0487], dtype=float32)}
# {'predictions': array([2319.2651], dtype=float32)}
# {'predictions': array([1874.3495], dtype=float32)}
# {'predictions': array([2119.4866], dtype=float32)}
# {'predictions': array([1889.0133], dtype=float32)}
# {'predictions': array([1647.1259], dtype=float32)}
# {'predictions': array([1757.212], dtype=float32)}
# {'predictions': array([2059.8525], dtype=float32)}
# {'predictions': array([1725.8737], dtype=float32)}
# {'predictions': array([4943.6016], dtype=float32)}
# {'predictions': array([1826.9392], dtype=float32)}
# {'predictions': array([1264.4982], dtype=float32)}
# {'predictions': array([1520.4447], dtype=float32)}
# {'predictions': array([1140.9872], dtype=float32)}
# {'predictions': array([1909.6066], dtype=float32)}
# {'predictions': array([1074.2957], dtype=float32)}
# {'predictions': array([1058.4254], dtype=float32)}
# {'predictions': array([4131.06], dtype=float32)}
# {'predictions': array([1271.8754], dtype=float32)}
# {'predictions': array([2684.5027], dtype=float32)}
# {'predictions': array([2117.8413], dtype=float32)}
# {'predictions': array([1156.5562], dtype=float32)}
# {'predictions': array([2472.27], dtype=float32)}
# {'predictions': array([2158.0342], dtype=float32)}
# {'predictions': array([1456.0586], dtype=float32)}
# {'predictions': array([1842.1527], dtype=float32)}
# {'predictions': array([2663.1658], dtype=float32)}
# {'predictions': array([3562.3674], dtype=float32)}
# {'predictions': array([1649.2562], dtype=float32)}
# {'predictions': array([1382.2472], dtype=float32)}
# {'predictions': array([1963.8986], dtype=float32)}
# {'predictions': array([1686.5607], dtype=float32)}
# {'predictions': array([806.30133], dtype=float32)}
# {'predictions': array([1729.1642], dtype=float32)}
# {'predictions': array([1890.6586], dtype=float32)}
# {'predictions': array([1500.5304], dtype=float32)}
# {'predictions': array([1907.1107], dtype=float32)}
# {'predictions': array([2164.6147], dtype=float32)}
# {'predictions': array([2133.8872], dtype=float32)}
# {'predictions': array([2898.4954], dtype=float32)}
# {'predictions': array([1758.298], dtype=float32)}
# {'predictions': array([1822.41], dtype=float32)}
# {'predictions': array([2060.9666], dtype=float32)}
# {'predictions': array([997.14606], dtype=float32)}
# {'predictions': array([1987.0338], dtype=float32)}
# {'predictions': array([1301.8661], dtype=float32)}
# {'predictions': array([1698.6637], dtype=float32)}
# {'predictions': array([1150.7562], dtype=float32)}
# {'predictions': array([1549.3046], dtype=float32)}
# {'predictions': array([1598.0046], dtype=float32)}
# {'predictions': array([2024.3651], dtype=float32)}
# {'predictions': array([1734.8074], dtype=float32)}
# {'predictions': array([1688.4403], dtype=float32)}
# {'predictions': array([1693.677], dtype=float32)}
# {'predictions': array([3324.749], dtype=float32)}
# {'predictions': array([1547.2529], dtype=float32)}
# {'predictions': array([1400.3445], dtype=float32)}
# {'predictions': array([1197.6178], dtype=float32)}
# {'predictions': array([1002.78925], dtype=float32)}
# {'predictions': array([1866.8309], dtype=float32)}
# {'predictions': array([2636.9065], dtype=float32)}
# {'predictions': array([1661.7898], dtype=float32)}
# {'predictions': array([830.0417], dtype=float32)}
# {'predictions': array([6914.67], dtype=float32)}
# {'predictions': array([1877.4967], dtype=float32)}
# {'predictions': array([2329.0852], dtype=float32)}
# {'predictions': array([2096.4536], dtype=float32)}
# {'predictions': array([1495.0636], dtype=float32)}
# {'predictions': array([1251.6229], dtype=float32)}
# {'predictions': array([1924.9447], dtype=float32)}
# {'predictions': array([3541.7744], dtype=float32)}
# {'predictions': array([2324.2007], dtype=float32)}
# {'predictions': array([1731.5168], dtype=float32)}
# {'predictions': array([806.30133], dtype=float32)}
# {'predictions': array([2648.3079], dtype=float32)}
# {'predictions': array([1101.4509], dtype=float32)}
# {'predictions': array([1334.5361], dtype=float32)}
# {'predictions': array([2336.6548], dtype=float32)}
# {'predictions': array([1550.2423], dtype=float32)}
# {'predictions': array([1656.7748], dtype=float32)}
# {'predictions': array([2147.433], dtype=float32)}
# {'predictions': array([4121.031], dtype=float32)}
# {'predictions': array([1758.298], dtype=float32)}
# {'predictions': array([1940.1581], dtype=float32)}
# {'predictions': array([1167.2595], dtype=float32)}
# {'predictions': array([1521.3868], dtype=float32)}
# {'predictions': array([1128.6199], dtype=float32)}
# {'predictions': array([2273.1992], dtype=float32)}
# {'predictions': array([1666.6971], dtype=float32)}
# {'predictions': array([2169.144], dtype=float32)}
# {'predictions': array([1616.8094], dtype=float32)}
# {'predictions': array([1592.7413], dtype=float32)}
# {'predictions': array([2302.1055], dtype=float32)}
# {'predictions': array([863.8837], dtype=float32)}
# {'predictions': array([1471.272], dtype=float32)}
# {'predictions': array([1903.9633], dtype=float32)}
# {'predictions': array([1235.8236], dtype=float32)}
# {'predictions': array([2140.2458], dtype=float32)}
# {'predictions': array([1970.4794], dtype=float32)}
# {'predictions': array([1574.6163], dtype=float32)}
# {'predictions': array([1819.651], dtype=float32)}
# {'predictions': array([1648.1835], dtype=float32)}
# {'predictions': array([1623.8195], dtype=float32)}
# {'predictions': array([1661.9735], dtype=float32)}
# {'predictions': array([1767.7628], dtype=float32)}
# {'predictions': array([748.7191], dtype=float32)}
# {'predictions': array([5107.4766], dtype=float32)}
# {'predictions': array([3966.0737], dtype=float32)}
# {'predictions': array([926.4018], dtype=float32)}
# {'predictions': array([1782.9249], dtype=float32)}
# {'predictions': array([5694.961], dtype=float32)}
# {'predictions': array([1716.7101], dtype=float32)}
# {'predictions': array([2001.031], dtype=float32)}
# {'predictions': array([2107.5637], dtype=float32)}
# {'predictions': array([1767.7628], dtype=float32)}
# {'predictions': array([1792.441], dtype=float32)}
# {'predictions': array([1643.1329], dtype=float32)}
# {'predictions': array([1401.8351], dtype=float32)}
# {'predictions': array([754.3619], dtype=float32)}
# {'predictions': array([2150.5288], dtype=float32)}
# {'predictions': array([2319.2651], dtype=float32)}
# {'predictions': array([839.8145], dtype=float32)}
# {'predictions': array([1327.0162], dtype=float32)}
# {'predictions': array([2890.9487], dtype=float32)}
# {'predictions': array([1729.3864], dtype=float32)}
# {'predictions': array([2342.2979], dtype=float32)}
# {'predictions': array([1333.4261], dtype=float32)}
# {'predictions': array([1043.8685], dtype=float32)}
# {'predictions': array([935.3354], dtype=float32)}
# {'predictions': array([1707.6332], dtype=float32)}
# {'predictions': array([1101.4509], dtype=float32)}
# {'predictions': array([3299.9006], dtype=float32)}
# {'predictions': array([1317.8196], dtype=float32)}
# {'predictions': array([1180.8276], dtype=float32)}
# {'predictions': array([1886.5734], dtype=float32)}
# {'predictions': array([1074.2957], dtype=float32)}
# {'predictions': array([1416.6245], dtype=float32)}
# {'predictions': array([2132.9495], dtype=float32)}
# {'predictions': array([1156.5562], dtype=float32)}
# {'predictions': array([1416.7965], dtype=float32)}
# {'predictions': array([2081.9478], dtype=float32)}
# {'predictions': array([1632.8551], dtype=float32)}
# {'predictions': array([2292.9417], dtype=float32)}
# {'predictions': array([1332.7186], dtype=float32)}
# {'predictions': array([1770.701], dtype=float32)}
# {'predictions': array([1400.3445], dtype=float32)}
# {'predictions': array([1820.3584], dtype=float32)}
# {'predictions': array([2105.3872], dtype=float32)}
# {'predictions': array([1216.616], dtype=float32)}
# {'predictions': array([755.95734], dtype=float32)}
# {'predictions': array([1367.4403], dtype=float32)}
# {'predictions': array([2063.355], dtype=float32)}
# {'predictions': array([1482.6049], dtype=float32)}
# {'predictions': array([2394.2693], dtype=float32)}
# {'predictions': array([1334.5361], dtype=float32)}
# {'predictions': array([1767.7628], dtype=float32)}
# {'predictions': array([1539.4333], dtype=float32)}
# {'predictions': array([966.59454], dtype=float32)}
# {'predictions': array([2564.351], dtype=float32)}
# {'predictions': array([1608.5323], dtype=float32)}
# {'predictions': array([93.89437], dtype=float32)}
# {'predictions': array([1132.7611], dtype=float32)}
# {'predictions': array([2274.8442], dtype=float32)}
# {'predictions': array([2081.9478], dtype=float32)}
# {'predictions': array([1461.0453], dtype=float32)}
# {'predictions': array([3803.1462], dtype=float32)}
# {'predictions': array([1605.7732], dtype=float32)}
# {'predictions': array([6259.7734], dtype=float32)}
# {'predictions': array([2536.6914], dtype=float32)}
# {'predictions': array([1988.628], dtype=float32)}
# {'predictions': array([2024.7715], dtype=float32)}
# {'predictions': array([1660.8239], dtype=float32)}
# {'predictions': array([1077.7616], dtype=float32)}
# {'predictions': array([1230.2352], dtype=float32)}
# {'predictions': array([1756.9896], dtype=float32)}
# {'predictions': array([2992.1064], dtype=float32)}
# {'predictions': array([1708.234], dtype=float32)}
# {'predictions': array([1155.0654], dtype=float32)}
# {'predictions': array([1408.3984], dtype=float32)}
# {'predictions': array([7746.0176], dtype=float32)}
# {'predictions': array([2065.851], dtype=float32)}
# {'predictions': array([932.045], dtype=float32)}
# {'predictions': array([1079.67], dtype=float32)}
# {'predictions': array([2063.8503], dtype=float32)}
# {'predictions': array([1001.144], dtype=float32)}
# {'predictions': array([1814.7153], dtype=float32)}
# {'predictions': array([1735.7452], dtype=float32)}
# {'predictions': array([1758.2468], dtype=float32)}
# {'predictions': array([1017.5961], dtype=float32)}
# {'predictions': array([1816.3607], dtype=float32)}
# {'predictions': array([6013.083], dtype=float32)}
# {'predictions': array([3095.0479], dtype=float32)}
# {'predictions': array([1401.8469], dtype=float32)}
# {'predictions': array([1012.6606], dtype=float32)}
# {'predictions': array([1990.2219], dtype=float32)}
# {'predictions': array([1758.298], dtype=float32)}
# {'predictions': array([926.4018], dtype=float32)}
# {'predictions': array([2160.867], dtype=float32)}
# {'predictions': array([1413.3341], dtype=float32)}
# {'predictions': array([1930.1436], dtype=float32)}
# {'predictions': array([1484.1073], dtype=float32)}
# {'predictions': array([2030.6449], dtype=float32)}
# {'predictions': array([1924.9447], dtype=float32)}
# {'predictions': array([1699.7726], dtype=float32)}
# {'predictions': array([1400.3445], dtype=float32)}
# {'predictions': array([2308.6353], dtype=float32)}
# {'predictions': array([1975.7242], dtype=float32)}
# {'predictions': array([1588.7897], dtype=float32)}
# {'predictions': array([3162.5527], dtype=float32)}
# {'predictions': array([1023.27594], dtype=float32)}
# {'predictions': array([1404.2216], dtype=float32)}
# {'predictions': array([5599.5386], dtype=float32)}
# {'predictions': array([1699.0189], dtype=float32)}
# {'predictions': array([2648.3079], dtype=float32)}
# {'predictions': array([1521.1516], dtype=float32)}
# {'predictions': array([2801.872], dtype=float32)}
# {'predictions': array([1112.4329], dtype=float32)}
# {'predictions': array([1724.4916], dtype=float32)}
# {'predictions': array([1005.27106], dtype=float32)}
# {'predictions': array([754.3619], dtype=float32)}
# {'predictions': array([2478.7998], dtype=float32)}
# {'predictions': array([1193.9894], dtype=float32)}
# {'predictions': array([2335.7173], dtype=float32)}
# {'predictions': array([1076.5228], dtype=float32)}
# {'predictions': array([2266.6182], dtype=float32)}
# {'predictions': array([2249.0522], dtype=float32)}
# {'predictions': array([1681.453], dtype=float32)}
# {'predictions': array([1166.0206], dtype=float32)}
# {'predictions': array([1286.6821], dtype=float32)}
# {'predictions': array([1697.2716], dtype=float32)}
# {'predictions': array([2331.7192], dtype=float32)}
# {'predictions': array([1660.8239], dtype=float32)}
# {'predictions': array([2508.058], dtype=float32)}
# {'predictions': array([1437.0746], dtype=float32)}
# {'predictions': array([2465.8042], dtype=float32)}
# {'predictions': array([1444.7651], dtype=float32)}
# {'predictions': array([1214.2632], dtype=float32)}
# {'predictions': array([3293.4902], dtype=float32)}
# {'predictions': array([1214.5775], dtype=float32)}
# {'predictions': array([1147.2671], dtype=float32)}
# {'predictions': array([1517.6903], dtype=float32)}
# {'predictions': array([1405.1375], dtype=float32)}
# {'predictions': array([1660.8239], dtype=float32)}
# {'predictions': array([1652.7687], dtype=float32)}
# {'predictions': array([1400.3445], dtype=float32)}
# {'predictions': array([1964.7443], dtype=float32)}
# {'predictions': array([1333.375], dtype=float32)}
# {'predictions': array([1085.4052], dtype=float32)}
# {'predictions': array([1593.0177], dtype=float32)}
# {'predictions': array([1825.7006], dtype=float32)}
# {'predictions': array([1517.338], dtype=float32)}
# {'predictions': array([178.52222], dtype=float32)}
# {'predictions': array([1625.3724], dtype=float32)}
# {'predictions': array([2128.0137], dtype=float32)}
# {'predictions': array([2445.239], dtype=float32)}
# {'predictions': array([1903.0256], dtype=float32)}
# {'predictions': array([1856.7753], dtype=float32)}
# {'predictions': array([1342.0587], dtype=float32)}
# {'predictions': array([3293.4902], dtype=float32)}
# {'predictions': array([1203.5052], dtype=float32)}
# {'predictions': array([2128.0137], dtype=float32)}
# {'predictions': array([1533.7902], dtype=float32)}
# {'predictions': array([1662.4691], dtype=float32)}
# {'predictions': array([1666.9092], dtype=float32)}
# {'predictions': array([2401.5256], dtype=float32)}
# {'predictions': array([1431.4315], dtype=float32)}
# {'predictions': array([1411.2087], dtype=float32)}
# {'predictions': array([1767.7628], dtype=float32)}
# {'predictions': array([1418.6251], dtype=float32)}
# {'predictions': array([1132.7611], dtype=float32)}
# {'predictions': array([1696.9674], dtype=float32)}
# {'predictions': array([1291.6394], dtype=float32)}
# {'predictions': array([1944.6873], dtype=float32)}
# {'predictions': array([8235.636], dtype=float32)}
# {'predictions': array([2010.496], dtype=float32)}
# {'predictions': array([1140.9872], dtype=float32)}
# {'predictions': array([2319.2651], dtype=float32)}
# {'predictions': array([1690.7931], dtype=float32)}
# {'predictions': array([3801.552], dtype=float32)}
# {'predictions': array([2156.338], dtype=float32)}
# {'predictions': array([1578.5631], dtype=float32)}
# {'predictions': array([1773.9915], dtype=float32)}
# {'predictions': array([1822.0038], dtype=float32)}
# {'predictions': array([1905.6088], dtype=float32)}
# {'predictions': array([2799.9258], dtype=float32)}
# {'predictions': array([1515.7438], dtype=float32)}
# {'predictions': array([1657.1813], dtype=float32)}
# {'predictions': array([1924.9447], dtype=float32)}
# {'predictions': array([1730.3293], dtype=float32)}
# {'predictions': array([2054.3855], dtype=float32)}
# {'predictions': array([2115.7898], dtype=float32)}
# {'predictions': array([1515.6927], dtype=float32)}
# {'predictions': array([1342.0587], dtype=float32)}
# {'predictions': array([1398.7495], dtype=float32)}
# {'predictions': array([913.2402], dtype=float32)}
# {'predictions': array([1941.66], dtype=float32)}
# {'predictions': array([2241.2324], dtype=float32)}
# {'predictions': array([2401.5256], dtype=float32)}
# {'predictions': array([1077.7616], dtype=float32)}
# {'predictions': array([2154.7437], dtype=float32)}
# {'predictions': array([1013.4551], dtype=float32)}
# {'predictions': array([1002.78925], dtype=float32)}
# {'predictions': array([1658.6832], dtype=float32)}
# {'predictions': array([1602.9403], dtype=float32)}
# {'predictions': array([1418.2698], dtype=float32)}
# {'predictions': array([1643.1329], dtype=float32)}
# {'predictions': array([2055.2722], dtype=float32)}
# {'predictions': array([1168.2484], dtype=float32)}
# {'predictions': array([1763.6216], dtype=float32)}
# {'predictions': array([2319.2651], dtype=float32)}
# {'predictions': array([1810.0529], dtype=float32)}
# {'predictions': array([1474.9147], dtype=float32)}
# {'predictions': array([2799.9258], dtype=float32)}
# {'predictions': array([2195.874], dtype=float32)}
# {'predictions': array([1990.2219], dtype=float32)}
# {'predictions': array([935.3354], dtype=float32)}
# {'predictions': array([2072.483], dtype=float32)}
# {'predictions': array([2546.3044], dtype=float32)}
# {'predictions': array([1403.3374], dtype=float32)}
# {'predictions': array([1820.0575], dtype=float32)}
# {'predictions': array([1655.536], dtype=float32)}
# {'predictions': array([1714.3573], dtype=float32)}
# {'predictions': array([1546.7682], dtype=float32)}
# {'predictions': array([1515.6927], dtype=float32)}
# {'predictions': array([2968.3662], dtype=float32)}
# {'predictions': array([2001.031], dtype=float32)}
# {'predictions': array([2119.7876], dtype=float32)}
# {'predictions': array([1515.7438], dtype=float32)}
# {'predictions': array([1687.0961], dtype=float32)}
# {'predictions': array([2168.8943], dtype=float32)}
# {'predictions': array([932.045], dtype=float32)}
# {'predictions': array([2306.3616], dtype=float32)}
# {'predictions': array([9502.531], dtype=float32)}
# {'predictions': array([1374.1122], dtype=float32)}
# {'predictions': array([799.5777], dtype=float32)}
# {'predictions': array([2005.9667], dtype=float32)}
# {'predictions': array([2195.874], dtype=float32)}
# {'predictions': array([3967.6677], dtype=float32)}
# {'predictions': array([6013.083], dtype=float32)}
# {'predictions': array([1816.7671], dtype=float32)}
# {'predictions': array([1646.9034], dtype=float32)}
# {'predictions': array([1582.8198], dtype=float32)}
# {'predictions': array([1814.7153], dtype=float32)}
# {'predictions': array([1244.5846], dtype=float32)}
# {'predictions': array([2320.504], dtype=float32)}
# {'predictions': array([2317.671], dtype=float32)}
# {'predictions': array([1667.76], dtype=float32)}
# {'predictions': array([1568.1964], dtype=float32)}
# {'predictions': array([1345.8295], dtype=float32)}
# {'predictions': array([2065.851], dtype=float32)}
# {'predictions': array([1813.7777], dtype=float32)}
# {'predictions': array([1503.7699], dtype=float32)}
# {'predictions': array([1924.9447], dtype=float32)}
# {'predictions': array([1517.338], dtype=float32)}
# {'predictions': array([2273.1992], dtype=float32)}
# {'predictions': array([3857.799], dtype=float32)}
# {'predictions': array([1514.8237], dtype=float32)}
# {'predictions': array([1660.2875], dtype=float32)}
# {'predictions': array([2238.2432], dtype=float32)}
# {'predictions': array([1951.6747], dtype=float32)}
# {'predictions': array([1586.7382], dtype=float32)}
# {'predictions': array([1577.8843], dtype=float32)}
# {'predictions': array([1339.4717], dtype=float32)}
# {'predictions': array([1632.8551], dtype=float32)}
# {'predictions': array([779.0401], dtype=float32)}
# {'predictions': array([3211.2295], dtype=float32)}
# {'predictions': array([1627.9194], dtype=float32)}
# {'predictions': array([754.3619], dtype=float32)}
# {'predictions': array([2147.433], dtype=float32)}
# {'predictions': array([1811.647], dtype=float32)}
# {'predictions': array([1447.3524], dtype=float32)}
# {'predictions': array([1509.413], dtype=float32)}
# {'predictions': array([1319.0256], dtype=float32)}
# {'predictions': array([1508.2252], dtype=float32)}
# {'predictions': array([1548.4133], dtype=float32)}
# {'predictions': array([2296.7634], dtype=float32)}
# {'predictions': array([1084.3215], dtype=float32)}
# {'predictions': array([2635.4043], dtype=float32)}
# {'predictions': array([2324.2007], dtype=float32)}
# {'predictions': array([1977.3186], dtype=float32)}
# {'predictions': array([1573.2753], dtype=float32)}
# {'predictions': array([1253.2172], dtype=float32)}
# {'predictions': array([1534.1425], dtype=float32)}
# {'predictions': array([2307.9556], dtype=float32)}
# {'predictions': array([1325.2512], dtype=float32)}
# {'predictions': array([2799.9258], dtype=float32)}
# {'predictions': array([1392.1184], dtype=float32)}
# {'predictions': array([1352.4613], dtype=float32)}
# {'predictions': array([1406.1708], dtype=float32)}
# {'predictions': array([912.0014], dtype=float32)}
# {'predictions': array([1555.8854], dtype=float32)}
# {'predictions': array([3622.5332], dtype=float32)}
# {'predictions': array([1482.6049], dtype=float32)}
# {'predictions': array([1686.3887], dtype=float32)}
# {'predictions': array([1986.0809], dtype=float32)}
# {'predictions': array([1676.5172], dtype=float32)}
# {'predictions': array([1166.0206], dtype=float32)}
# {'predictions': array([1814.1842], dtype=float32)}
# {'predictions': array([1165.6654], dtype=float32)}
# {'predictions': array([3622.5332], dtype=float32)}
# {'predictions': array([1701.4177], dtype=float32)}
# {'predictions': array([1517.6903], dtype=float32)}
# {'predictions': array([882.6374], dtype=float32)}
# {'predictions': array([1408.7539], dtype=float32)}
# {'predictions': array([1963.191], dtype=float32)}
# {'predictions': array([1573.2753], dtype=float32)}
# {'predictions': array([1510.4305], dtype=float32)}
# {'predictions': array([2648.3079], dtype=float32)}
# {'predictions': array([1933.0277], dtype=float32)}
# {'predictions': array([1566.3678], dtype=float32)}
# {'predictions': array([2250.166], dtype=float32)}
# {'predictions': array([2680.505], dtype=float32)}
# {'predictions': array([1297.2826], dtype=float32)}
# {'predictions': array([1633.2104], dtype=float32)}
# {'predictions': array([1459.4003], dtype=float32)}
# {'predictions': array([1563.0773], dtype=float32)}
# {'predictions': array([1632.319], dtype=float32)}
# {'predictions': array([5599.5386], dtype=float32)}
# {'predictions': array([1521.3868], dtype=float32)}
# {'predictions': array([1864.4781], dtype=float32)}
# {'predictions': array([1367.4403], dtype=float32)}
# {'predictions': array([1769.3568], dtype=float32)}
# {'predictions': array([3055.5625], dtype=float32)}
# {'predictions': array([1539.0779], dtype=float32)}
# {'predictions': array([1762.475], dtype=float32)}
# {'predictions': array([1890.6174], dtype=float32)}
# {'predictions': array([1002.78925], dtype=float32)}
# {'predictions': array([1905.6088], dtype=float32)}
# {'predictions': array([1122.8898], dtype=float32)}
# {'predictions': array([1468.3339], dtype=float32)}
# {'predictions': array([2633.501], dtype=float32)}
# {'predictions': array([1826.9392], dtype=float32)}
# {'predictions': array([1574.5938], dtype=float32)}
# {'predictions': array([1696.9674], dtype=float32)}
# {'predictions': array([1982.7906], dtype=float32)}
# {'predictions': array([1809.6364], dtype=float32)}
# {'predictions': array([2536.6914], dtype=float32)}
# {'predictions': array([1814.9786], dtype=float32)}
# {'predictions': array([1717.0653], dtype=float32)}
# {'predictions': array([1820.0575], dtype=float32)}
# {'predictions': array([1751.666], dtype=float32)}
# {'predictions': array([1773.9915], dtype=float32)}
# {'predictions': array([1517.338], dtype=float32)}
# {'predictions': array([1902.175], dtype=float32)}
# {'predictions': array([1719.293], dtype=float32)}
# {'predictions': array([1593.0177], dtype=float32)}
# {'predictions': array([829.74066], dtype=float32)}
# {'predictions': array([1927.5194], dtype=float32)}
# {'predictions': array([1575.2726], dtype=float32)}
# {'predictions': array([1064.0686], dtype=float32)}
# {'predictions': array([754.3619], dtype=float32)}
# {'predictions': array([1082.5216], dtype=float32)}
# {'predictions': array([1658.6832], dtype=float32)}
# {'predictions': array([991.27277], dtype=float32)}
# {'predictions': array([2279.78], dtype=float32)}
# {'predictions': array([1583.1466], dtype=float32)}
# {'predictions': array([1765.5809], dtype=float32)}
# {'predictions': array([1043.8685], dtype=float32)}
# {'predictions': array([723.1028], dtype=float32)}
# {'predictions': array([1168.8536], dtype=float32)}
# {'predictions': array([1946.1893], dtype=float32)}
# {'predictions': array([3996.956], dtype=float32)}
# {'predictions': array([1367.4403], dtype=float32)}
# {'predictions': array([1920.0092], dtype=float32)}
# {'predictions': array([2041.755], dtype=float32)}
# {'predictions': array([1773.0537], dtype=float32)}
# {'predictions': array([2277.4272], dtype=float32)}
# {'predictions': array([1681.453], dtype=float32)}
# {'predictions': array([1544.9513], dtype=float32)}
# {'predictions': array([1920.0092], dtype=float32)}
# {'predictions': array([2598.9514], dtype=float32)}
# {'predictions': array([1859.3994], dtype=float32)}
# {'predictions': array([1281.1858], dtype=float32)}
# {'predictions': array([1825.7006], dtype=float32)}
# {'predictions': array([2315.1238], dtype=float32)}
# {'predictions': array([1529.562], dtype=float32)}
# {'predictions': array([1792.441], dtype=float32)}
# {'predictions': array([1464.9922], dtype=float32)}
# {'predictions': array([2061.7097], dtype=float32)}
# {'predictions': array([1318.0841], dtype=float32)}
# {'predictions': array([1819.651], dtype=float32)}
# {'predictions': array([1021.7735], dtype=float32)}
# {'predictions': array([2160.0674], dtype=float32)}
# {'predictions': array([1615.2153], dtype=float32)}
# {'predictions': array([1367.4403], dtype=float32)}
# {'predictions': array([1503.7699], dtype=float32)}
# {'predictions': array([1101.4509], dtype=float32)}
# {'predictions': array([1450.5917], dtype=float32)}
# {'predictions': array([1583.1466], dtype=float32)}
# {'predictions': array([1239.7001], dtype=float32)}
# {'predictions': array([2964.4473], dtype=float32)}
# {'predictions': array([1998.4481], dtype=float32)}
# {'predictions': array([1889.1564], dtype=float32)}
# {'predictions': array([1661.2302], dtype=float32)}
# {'predictions': array([1374.0212], dtype=float32)}
# {'predictions': array([1001.9386], dtype=float32)}
# {'predictions': array([1566.3561], dtype=float32)}
# {'predictions': array([1001.144], dtype=float32)}
# {'predictions': array([1329.6006], dtype=float32)}
# {'predictions': array([1920.4156], dtype=float32)}
# {'predictions': array([2156.338], dtype=float32)}
# {'predictions': array([1506.1737], dtype=float32)}
# {'predictions': array([1253.778], dtype=float32)}
# {'predictions': array([932.045], dtype=float32)}
# {'predictions': array([1597.9535], dtype=float32)}
# {'predictions': array([1986.1731], dtype=float32)}
# {'predictions': array([1957.3179], dtype=float32)}
# {'predictions': array([1566.0187], dtype=float32)}
# {'predictions': array([2906.149], dtype=float32)}
# {'predictions': array([2076.3047], dtype=float32)}
# {'predictions': array([1940.1581], dtype=float32)}
# {'predictions': array([2403.12], dtype=float32)}
# {'predictions': array([1694.0834], dtype=float32)}
# {'predictions': array([3293.4902], dtype=float32)}
# {'predictions': array([2140.8232], dtype=float32)}
# {'predictions': array([1423.8618], dtype=float32)}
# {'predictions': array([1990.1487], dtype=float32)}
# {'predictions': array([840.70795], dtype=float32)}
# {'predictions': array([1417.503], dtype=float32)}
# {'predictions': array([2018.0063], dtype=float32)}
# {'predictions': array([2109.6152], dtype=float32)}
# {'predictions': array([1602.9403], dtype=float32)}
# {'predictions': array([1882.5756], dtype=float32)}
# {'predictions': array([1385.3655], dtype=float32)}
# {'predictions': array([918.8833], dtype=float32)}
# {'predictions': array([1184.4562], dtype=float32)}
# {'predictions': array([1413.3341], dtype=float32)}
# {'predictions': array([2049.501], dtype=float32)}
# {'predictions': array([1581.3582], dtype=float32)}
# {'predictions': array([1544.9513], dtype=float32)}
# {'predictions': array([2142.3252], dtype=float32)}
# {'predictions': array([2111.2607], dtype=float32)}
# {'predictions': array([1534.1425], dtype=float32)}
# {'predictions': array([1043.8685], dtype=float32)}
# {'predictions': array([757.5556], dtype=float32)}
# {'predictions': array([1002.78925], dtype=float32)}
# {'predictions': array([1564.1115], dtype=float32)}
# {'predictions': array([1818.7131], dtype=float32)}
# {'predictions': array([3851.218], dtype=float32)}
# {'predictions': array([875.2071], dtype=float32)}
# {'predictions': array([1754.2489], dtype=float32)}
# {'predictions': array([3019.04], dtype=float32)}
# {'predictions': array([1161.6163], dtype=float32)}
# {'predictions': array([3299.1333], dtype=float32)}
# {'predictions': array([1414.0416], dtype=float32)}
# {'predictions': array([1786.8591], dtype=float32)}
# {'predictions': array([1277.54], dtype=float32)}
# {'predictions': array([3996.956], dtype=float32)}
# {'predictions': array([1826.9392], dtype=float32)}
# {'predictions': array([1450.5917], dtype=float32)}
# {'predictions': array([1574.514], dtype=float32)}
# {'predictions': array([1392.1184], dtype=float32)}
# {'predictions': array([1155.0654], dtype=float32)}
# {'predictions': array([932.045], dtype=float32)}
# {'predictions': array([1275.3588], dtype=float32)}
# {'predictions': array([1297.2826], dtype=float32)}
# {'predictions': array([507.5823], dtype=float32)}
# {'predictions': array([1515.6927], dtype=float32)}
# {'predictions': array([1713.4197], dtype=float32)}
# {'predictions': array([927.05817], dtype=float32)}
# {'predictions': array([2128.0137], dtype=float32)}
# {'predictions': array([1408.3984], dtype=float32)}
# {'predictions': array([927.05817], dtype=float32)}
# {'predictions': array([1017.5961], dtype=float32)}
# {'predictions': array([2547.8987], dtype=float32)}
# {'predictions': array([1465.0433], dtype=float32)}
# {'predictions': array([1319.5746], dtype=float32)}
# {'predictions': array([1431.4315], dtype=float32)}
# {'predictions': array([1100.2633], dtype=float32)}
# {'predictions': array([3622.5332], dtype=float32)}
# {'predictions': array([1698.6637], dtype=float32)}
# {'predictions': array([2306.3616], dtype=float32)}
# {'predictions': array([836.6226], dtype=float32)}
# {'predictions': array([1981.3674], dtype=float32)}
# {'predictions': array([1573.2753], dtype=float32)}
# {'predictions': array([1880.9304], dtype=float32)}
# {'predictions': array([1680.9218], dtype=float32)}
# {'predictions': array([3301.9893], dtype=float32)}
# {'predictions': array([1550.2423], dtype=float32)}
# {'predictions': array([1945.8011], dtype=float32)}
# {'predictions': array([932.045], dtype=float32)}
# {'predictions': array([1554.0558], dtype=float32)}
# {'predictions': array([1596.6095], dtype=float32)}
# {'predictions': array([3293.4902], dtype=float32)}
# {'predictions': array([1730.6661], dtype=float32)}
# {'predictions': array([1650.9012], dtype=float32)}
# {'predictions': array([1232.716], dtype=float32)}
# {'predictions': array([1401.8469], dtype=float32)}
# {'predictions': array([1549.3046], dtype=float32)}
# {'predictions': array([3622.5332], dtype=float32)}
# {'predictions': array([2812.8293], dtype=float32)}
# {'predictions': array([1482.6049], dtype=float32)}
# {'predictions': array([1751.666], dtype=float32)}
# {'predictions': array([1043.8685], dtype=float32)}
# {'predictions': array([780.6853], dtype=float32)}
# {'predictions': array([1745.8285], dtype=float32)}
# {'predictions': array([2898.6387], dtype=float32)}
# {'predictions': array([1012.6606], dtype=float32)}
# {'predictions': array([1244.2323], dtype=float32)}
# {'predictions': array([2044.1077], dtype=float32)}
# {'predictions': array([1691.1812], dtype=float32)}
# {'predictions': array([1515.6927], dtype=float32)}
# {'predictions': array([1378.9568], dtype=float32)}
# {'predictions': array([3443.0615], dtype=float32)}
# {'predictions': array([1634.005], dtype=float32)}
# {'predictions': array([1578.5631], dtype=float32)}
# {'predictions': array([1752.6036], dtype=float32)}
# {'predictions': array([1197.6178], dtype=float32)}
# {'predictions': array([1484.1073], dtype=float32)}
# {'predictions': array([1193.2819], dtype=float32)}
# {'predictions': array([1170.4484], dtype=float32)}
# {'predictions': array([1726.2803], dtype=float32)}
# {'predictions': array([1466.1528], dtype=float32)}
# {'predictions': array([1232.716], dtype=float32)}
# {'predictions': array([2719.1672], dtype=float32)}
# {'predictions': array([2292.9417], dtype=float32)}
# {'predictions': array([2119.4866], dtype=float32)}
# {'predictions': array([1632.5029], dtype=float32)}
# {'predictions': array([1655.1808], dtype=float32)}
# {'predictions': array([2107.5637], dtype=float32)}
# {'predictions': array([1564.8654], dtype=float32)}
# {'predictions': array([1652.7687], dtype=float32)}
# {'predictions': array([1662.4178], dtype=float32)}
# {'predictions': array([1628.2748], dtype=float32)}
# {'predictions': array([1401.8469], dtype=float32)}
# {'predictions': array([1524.2198], dtype=float32)}
# {'predictions': array([1878.9574], dtype=float32)}
# {'predictions': array([1506.5289], dtype=float32)}
# {'predictions': array([1762.475], dtype=float32)}
# {'predictions': array([2331.7192], dtype=float32)}
# {'predictions': array([1686.3887], dtype=float32)}
# {'predictions': array([1607.4183], dtype=float32)}
# {'predictions': array([1001.144], dtype=float32)}
# {'predictions': array([1323.7257], dtype=float32)}
# {'predictions': array([1400.3445], dtype=float32)}
# {'predictions': array([2094.6653], dtype=float32)}
# {'predictions': array([2063.355], dtype=float32)}
# {'predictions': array([1903.0256], dtype=float32)}
# {'predictions': array([1889.4574], dtype=float32)}
# {'predictions': array([1459.4003], dtype=float32)}
# {'predictions': array([1414.0416], dtype=float32)}
# {'predictions': array([1414.0416], dtype=float32)}
# {'predictions': array([1691.3243], dtype=float32)}
# {'predictions': array([2638.0874], dtype=float32)}
# {'predictions': array([1619.6934], dtype=float32)}
# {'predictions': array([2080.3025], dtype=float32)}
# {'predictions': array([1331.7809], dtype=float32)}
# {'predictions': array([1578.9183], dtype=float32)}
# {'predictions': array([1645.9658], dtype=float32)}
# {'predictions': array([1079.5287], dtype=float32)}
# {'predictions': array([3924.3145], dtype=float32)}
# {'predictions': array([3624.127], dtype=float32)}
# {'predictions': array([1408.3984], dtype=float32)}
# {'predictions': array([2105.3872], dtype=float32)}
# {'predictions': array([1547.2529], dtype=float32)}
# {'predictions': array([2069.141], dtype=float32)}
# {'predictions': array([2381.7832], dtype=float32)}
# {'predictions': array([1549.8358], dtype=float32)}
# {'predictions': array([935.3354], dtype=float32)}
# {'predictions': array([2158.0342], dtype=float32)}
# {'predictions': array([1965.544], dtype=float32)}
# {'predictions': array([1417.7386], dtype=float32)}
# {'predictions': array([1597.9535], dtype=float32)}
# {'predictions': array([1437.0746], dtype=float32)}
# {'predictions': array([2230.4233], dtype=float32)}
# {'predictions': array([1488.2472], dtype=float32)}
# {'predictions': array([966.59454], dtype=float32)}
# {'predictions': array([1773.9915], dtype=float32)}
# {'predictions': array([2154.7437], dtype=float32)}
# {'predictions': array([2072.483], dtype=float32)}
# {'predictions': array([1828.0991], dtype=float32)}
# {'predictions': array([6177.7065], dtype=float32)}
# {'predictions': array([1676.5172], dtype=float32)}
# {'predictions': array([1831.4308], dtype=float32)}
# {'predictions': array([1193.9894], dtype=float32)}
# {'predictions': array([1822.41], dtype=float32)}
# {'predictions': array([1242.6893], dtype=float32)}
# {'predictions': array([2543.952], dtype=float32)}
# {'predictions': array([1253.2172], dtype=float32)}
# {'predictions': array([4428.6924], dtype=float32)}
# {'predictions': array([2968.3662], dtype=float32)}
# {'predictions': array([1218.7188], dtype=float32)}
# {'predictions': array([2120.245], dtype=float32)}
# {'predictions': array([3624.0352], dtype=float32)}
# {'predictions': array([2133.8872], dtype=float32)}
# {'predictions': array([830.97955], dtype=float32)}
# {'predictions': array([2301.1167], dtype=float32)}
# {'predictions': array([2227.133], dtype=float32)}
# {'predictions': array([1697.2716], dtype=float32)}
# {'predictions': array([1989.8667], dtype=float32)}
# {'predictions': array([1810.0529], dtype=float32)}
# {'predictions': array([3722.7478], dtype=float32)}
# {'predictions': array([2128.0137], dtype=float32)}
# {'predictions': array([1819.651], dtype=float32)}
# {'predictions': array([5765.5615], dtype=float32)}
# {'predictions': array([1583.1466], dtype=float32)}
# {'predictions': array([1729.1642], dtype=float32)}
# {'predictions': array([2640.9785], dtype=float32)}
# {'predictions': array([1600.9171], dtype=float32)}
# {'predictions': array([1984.579], dtype=float32)}
# {'predictions': array([1084.9988], dtype=float32)}
# {'predictions': array([1722.9899], dtype=float32)}
# {'predictions': array([1923.2994], dtype=float32)}
# {'predictions': array([1966.7826], dtype=float32)}
# {'predictions': array([932.045], dtype=float32)}
# {'predictions': array([1378.2533], dtype=float32)}
# {'predictions': array([958.36835], dtype=float32)}
# {'predictions': array([1398.9337], dtype=float32)}
# {'predictions': array([4283.3667], dtype=float32)}
# {'predictions': array([1281.0013], dtype=float32)}
# {'predictions': array([1454.6364], dtype=float32)}
# {'predictions': array([1400.5277], dtype=float32)}
# {'predictions': array([1966.7826], dtype=float32)}
# {'predictions': array([924.70624], dtype=float32)}
# {'predictions': array([1324.5437], dtype=float32)}
# {'predictions': array([2635.4043], dtype=float32)}
# {'predictions': array([2156.338], dtype=float32)}
# {'predictions': array([918.8833], dtype=float32)}
# {'predictions': array([803.7183], dtype=float32)}
# {'predictions': array([1657.1813], dtype=float32)}
# {'predictions': array([1729.1642], dtype=float32)}
# {'predictions': array([1147.2671], dtype=float32)}
# {'predictions': array([997.00287], dtype=float32)}
# {'predictions': array([1507.2831], dtype=float32)}
# {'predictions': array([1431.4315], dtype=float32)}
# {'predictions': array([2319.2651], dtype=float32)}
# {'predictions': array([1197.6178], dtype=float32)}
# {'predictions': array([1038.9327], dtype=float32)}
# {'predictions': array([2132.0986], dtype=float32)}
# {'predictions': array([1401.8469], dtype=float32)}
# {'predictions': array([1824.1064], dtype=float32)}
# {'predictions': array([1411.2087], dtype=float32)}
# {'predictions': array([2312.0046], dtype=float32)}
# {'predictions': array([1621.2875], dtype=float32)}
# {'predictions': array([1150.8585], dtype=float32)}
# {'predictions': array([1083.8112], dtype=float32)}
# {'predictions': array([1126.1292], dtype=float32)}
# {'predictions': array([1494.1619], dtype=float32)}
# {'predictions': array([2068.4849], dtype=float32)}
# {'predictions': array([1489.1859], dtype=float32)}
# {'predictions': array([1544.9513], dtype=float32)}
# {'predictions': array([1660.2875], dtype=float32)}
# {'predictions': array([1870.1213], dtype=float32)}
# {'predictions': array([1599.4554], dtype=float32)}
# {'predictions': array([2039.5784], dtype=float32)}
# {'predictions': array([1164.4266], dtype=float32)}
# {'predictions': array([2138.2915], dtype=float32)}
# {'predictions': array([3583.7556], dtype=float32)}
# {'predictions': array([1759.1846], dtype=float32)}
# {'predictions': array([1401.8351], dtype=float32)}
# {'predictions': array([1877.4967], dtype=float32)}
# {'predictions': array([1594.5199], dtype=float32)}
# {'predictions': array([1411.2087], dtype=float32)}
# {'predictions': array([1657.038], dtype=float32)}
# {'predictions': array([1597.9535], dtype=float32)}
# {'predictions': array([1517.6903], dtype=float32)}
# {'predictions': array([1544.9513], dtype=float32)}
# {'predictions': array([1488.2472], dtype=float32)}
# {'predictions': array([1140.9872], dtype=float32)}
# {'predictions': array([1763.6216], dtype=float32)}
# {'predictions': array([1588.7897], dtype=float32)}
# {'predictions': array([1017.5961], dtype=float32)}
# {'predictions': array([1084.9988], dtype=float32)}
# {'predictions': array([1588.7897], dtype=float32)}
# {'predictions': array([1366.3304], dtype=float32)}
# {'predictions': array([1408.7539], dtype=float32)}
# {'predictions': array([1005.3721], dtype=float32)}
# {'predictions': array([875.2071], dtype=float32)}
# {'predictions': array([9502.531], dtype=float32)}
# {'predictions': array([1474.9147], dtype=float32)}
# {'predictions': array([1400.3445], dtype=float32)}
# {'predictions': array([3459.606], dtype=float32)}
# {'predictions': array([1482.6049], dtype=float32)}
# {'predictions': array([1990.2219], dtype=float32)}
# {'predictions': array([2543.952], dtype=float32)}
# {'predictions': array([2760.1826], dtype=float32)}
# {'predictions': array([1082.1659], dtype=float32)}
# {'predictions': array([1643.1329], dtype=float32)}
# {'predictions': array([1508.2252], dtype=float32)}
# {'predictions': array([1767.7628], dtype=float32)}
# {'predictions': array([1424.2682], dtype=float32)}
# {'predictions': array([1249.5201], dtype=float32)}
# {'predictions': array([2187.648], dtype=float32)}
# {'predictions': array([1812.3544], dtype=float32)}
# {'predictions': array([1370.965], dtype=float32)}
# {'predictions': array([1471.272], dtype=float32)}
# {'predictions': array([2508.058], dtype=float32)}
# {'predictions': array([876.0566], dtype=float32)}
# {'predictions': array([2154.7437], dtype=float32)}
# {'predictions': array([1559.9298], dtype=float32)}
# {'predictions': array([1632.8551], dtype=float32)}
# {'predictions': array([2968.3662], dtype=float32)}
# {'predictions': array([1825.2942], dtype=float32)}
# {'predictions': array([1126.1292], dtype=float32)}
# {'predictions': array([1676.5172], dtype=float32)}
# {'predictions': array([1345.8295], dtype=float32)}
# {'predictions': array([1767.7628], dtype=float32)}
# {'predictions': array([927.05817], dtype=float32)}
# {'predictions': array([1049.6176], dtype=float32)}
# {'predictions': array([1112.4329], dtype=float32)}
# {'predictions': array([1083.4047], dtype=float32)}
# {'predictions': array([1351.4723], dtype=float32)}
# {'predictions': array([1880.9304], dtype=float32)}
# {'predictions': array([1680.9218], dtype=float32)}
# {'predictions': array([754.3619], dtype=float32)}
# {'predictions': array([1924.9447], dtype=float32)}
# {'predictions': array([1074.2957], dtype=float32)}
# {'predictions': array([3801.552], dtype=float32)}
# {'predictions': array([3622.5332], dtype=float32)}
# {'predictions': array([1907.1107], dtype=float32)}
# {'predictions': array([2066.8398], dtype=float32)}
# {'predictions': array([1698.6127], dtype=float32)}
# {'predictions': array([4413.83], dtype=float32)}
# {'predictions': array([2094.8083], dtype=float32)}
# {'predictions': array([1963.191], dtype=float32)}
# {'predictions': array([4941.4526], dtype=float32)}
# {'predictions': array([971.47906], dtype=float32)}
# {'predictions': array([2069.141], dtype=float32)}
# {'predictions': array([3583.7556], dtype=float32)}
# {'predictions': array([1545.1635], dtype=float32)}
# {'predictions': array([5164.2637], dtype=float32)}
# {'predictions': array([705.00543], dtype=float32)}
# {'predictions': array([2292.9417], dtype=float32)}
# {'predictions': array([1717.0653], dtype=float32)}
# {'predictions': array([1924.9447], dtype=float32)}
# {'predictions': array([1275.3588], dtype=float32)}
# {'predictions': array([1614.4056], dtype=float32)}
# {'predictions': array([2536.6914], dtype=float32)}
# {'predictions': array([5275.1914], dtype=float32)}
# {'predictions': array([1761.5371], dtype=float32)}
# {'predictions': array([1598.0046], dtype=float32)}
# {'predictions': array([2394.9448], dtype=float32)}
# {'predictions': array([1825.7006], dtype=float32)}
# {'predictions': array([2315.216], dtype=float32)}
# {'predictions': array([1661.1791], dtype=float32)}
# {'predictions': array([1483.6625], dtype=float32)}
# {'predictions': array([1784.3859], dtype=float32)}
# {'predictions': array([1155.0654], dtype=float32)}
# {'predictions': array([1492.1613], dtype=float32)}
# {'predictions': array([1084.9988], dtype=float32)}
# {'predictions': array([2295.8257], dtype=float32)}
# {'predictions': array([2318.3123], dtype=float32)}
# {'predictions': array([2132.6484], dtype=float32)}
# {'predictions': array([1513.4979], dtype=float32)}
# {'predictions': array([901.1923], dtype=float32)}
# {'predictions': array([754.3619], dtype=float32)}
# {'predictions': array([2098.0989], dtype=float32)}
# {'predictions': array([1510.7572], dtype=float32)}
# {'predictions': array([1574.7772], dtype=float32)}
# {'predictions': array([1489.7216], dtype=float32)}
# {'predictions': array([1597.9535], dtype=float32)}
# {'predictions': array([1886.5734], dtype=float32)}
# {'predictions': array([1414.3971], dtype=float32)}
# {'predictions': array([1573.5763], dtype=float32)}
# {'predictions': array([1484.1073], dtype=float32)}
# {'predictions': array([1659.5851], dtype=float32)}
# {'predictions': array([1293.2335], dtype=float32)}
# {'predictions': array([2313.622], dtype=float32)}
# {'predictions': array([1740.6808], dtype=float32)}
# {'predictions': array([2970.0903], dtype=float32)}
# {'predictions': array([1661.2302], dtype=float32)}
# {'predictions': array([4118.8457], dtype=float32)}
# {'predictions': array([2181.5981], dtype=float32)}
# {'predictions': array([1922.0608], dtype=float32)}
# {'predictions': array([1084.9988], dtype=float32)}
# {'predictions': array([3294.9922], dtype=float32)}
# {'predictions': array([966.59454], dtype=float32)}
# {'predictions': array([1687.0961], dtype=float32)}
# {'predictions': array([1077.7616], dtype=float32)}
# {'predictions': array([1342.0587], dtype=float32)}
# {'predictions': array([1817.29], dtype=float32)}
# {'predictions': array([1007.0174], dtype=float32)}
# {'predictions': array([1080.8583], dtype=float32)}
# {'predictions': array([754.3619], dtype=float32)}
# {'predictions': array([1016.3063], dtype=float32)}
# {'predictions': array([1237.3258], dtype=float32)}
# {'predictions': array([1604.8353], dtype=float32)}
# {'predictions': array([1378.2533], dtype=float32)}
# {'predictions': array([1408.7539], dtype=float32)}
# {'predictions': array([1057.0813], dtype=float32)}
# {'predictions': array([1342.0587], dtype=float32)}
# {'predictions': array([1474.9147], dtype=float32)}
# {'predictions': array([1519.2842], dtype=float32)}
# {'predictions': array([2733.7568], dtype=float32)}
# {'predictions': array([1078.168], dtype=float32)}
# {'predictions': array([1251.6229], dtype=float32)}
# {'predictions': array([1001.144], dtype=float32)}
# {'predictions': array([966.59454], dtype=float32)}
# {'predictions': array([2284.008], dtype=float32)}
# {'predictions': array([1088.0394], dtype=float32)}
# {'predictions': array([1199.4562], dtype=float32)}
# {'predictions': array([2324.2007], dtype=float32)}
# {'predictions': array([1431.4315], dtype=float32)}
# {'predictions': array([1515.5092], dtype=float32)}
# {'predictions': array([1297.2826], dtype=float32)}
# {'predictions': array([4131.06], dtype=float32)}
# {'predictions': array([2317.671], dtype=float32)}
# {'predictions': array([1422.2678], dtype=float32)}
# {'predictions': array([1666.6971], dtype=float32)}
# {'predictions': array([2364.6553], dtype=float32)}
# {'predictions': array([1626.6808], dtype=float32)}
# {'predictions': array([1318.0841], dtype=float32)}
# {'predictions': array([1739.2987], dtype=float32)}
# {'predictions': array([1970.4794], dtype=float32)}
# {'predictions': array([1925.1569], dtype=float32)}
# {'predictions': array([1005.3721], dtype=float32)}
# {'predictions': array([2214.9092], dtype=float32)}
# {'predictions': array([1329.6006], dtype=float32)}
# {'predictions': array([1153.5631], dtype=float32)}
# {'predictions': array([1755.8942], dtype=float32)}
# {'predictions': array([3622.5332], dtype=float32)}
# {'predictions': array([976.4659], dtype=float32)}
# {'predictions': array([1655.536], dtype=float32)}
# ...
# {'predictions': array([1482.6049], dtype=float32)}
# {'predictions': array([1400.3445], dtype=float32)}
# {'predictions': array([2223.8425], dtype=float32)}
# {'predictions': array([1687.0961], dtype=float32)}
# {'predictions': array([2176.1313], dtype=float32)}
# {'predictions': array([1170.7208], dtype=float32)}
# {'predictions': array([754.3619], dtype=float32)}
# {'predictions': array([2084.5308], dtype=float32)}
# {'predictions': array([1658.6832], dtype=float32)}
# {'predictions': array([1593.0177], dtype=float32)}
# {'predictions': array([2306.3616], dtype=float32)}
# {'predictions': array([1408.7539], dtype=float32)}
# {'predictions': array([1939.2203], dtype=float32)}
# {'predictions': array([932.045], dtype=float32)}
# {'predictions': array([2390.4631], dtype=float32)}
# {'predictions': array([3578.1125], dtype=float32)}
# {'predictions': array([2320.504], dtype=float32)}
# {'predictions': array([1017.2951], dtype=float32)}
# {'predictions': array([926.4018], dtype=float32)}
# {'predictions': array([3965.7183], dtype=float32)}
# {'predictions': array([2472.385], dtype=float32)}
# {'predictions': array([750.22144], dtype=float32)}
# {'predictions': array([1615.2153], dtype=float32)}
# {'predictions': array([1674.8722], dtype=float32)}
# {'predictions': array([1772.3461], dtype=float32)}
# {'predictions': array([1290.6505], dtype=float32)}
# {'predictions': array([877.0455], dtype=float32)}
# {'predictions': array([2470.883], dtype=float32)}
# {'predictions': array([1122.8898], dtype=float32)}
# {'predictions': array([1022.93823], dtype=float32)}
# {'predictions': array([1198.5186], dtype=float32)}
# {'predictions': array([1911.2517], dtype=float32)}
# {'predictions': array([1156.5562], dtype=float32)}
# {'predictions': array([1539.4333], dtype=float32)}
# {'predictions': array([1221.6027], dtype=float32)}
# {'predictions': array([1858.6047], dtype=float32)}
# {'predictions': array([1249.5201], dtype=float32)}
# {'predictions': array([1457.1725], dtype=float32)}
# {'predictions': array([1568.1964], dtype=float32)}
# {'predictions': array([1515.5092], dtype=float32)}
# {'predictions': array([1632.5029], dtype=float32)}
# {'predictions': array([1924.9447], dtype=float32)}
# {'predictions': array([1566.3678], dtype=float32)}
# {'predictions': array([1583.1466], dtype=float32)}
# {'predictions': array([2150.5288], dtype=float32)}
# {'predictions': array([1864.4781], dtype=float32)}
# {'predictions': array([1504.9349], dtype=float32)}
# {'predictions': array([1870.1213], dtype=float32)}
# {'predictions': array([7746.0176], dtype=float32)}
# {'predictions': array([1879.9927], dtype=float32)}
# {'predictions': array([1145.1139], dtype=float32)}
# {'predictions': array([1079.3558], dtype=float32)}
# {'predictions': array([1465.0433], dtype=float32)}
# {'predictions': array([1249.0759], dtype=float32)}
# {'predictions': array([1176.6865], dtype=float32)}
# {'predictions': array([1658.6832], dtype=float32)}
# {'predictions': array([1333.375], dtype=float32)}
# {'predictions': array([3772.876], dtype=float32)}
# {'predictions': array([1550.5945], dtype=float32)}
# {'predictions': array([1072.805], dtype=float32)}
# {'predictions': array([2008.3195], dtype=float32)}
# {'predictions': array([1583.1466], dtype=float32)}
# {'predictions': array([1632.319], dtype=float32)}
# {'predictions': array([3622.5332], dtype=float32)}
# {'predictions': array([965.8365], dtype=float32)}
# {'predictions': array([1494.1619], dtype=float32)}
# {'predictions': array([1826.9392], dtype=float32)}
# {'predictions': array([1392.1184], dtype=float32)}
# {'predictions': array([2663.1658], dtype=float32)}
# {'predictions': array([1744.2344], dtype=float32)}
# {'predictions': array([1281.0013], dtype=float32)}
# {'predictions': array([1474.3789], dtype=float32)}
# {'predictions': array([1767.7628], dtype=float32)}
# {'predictions': array([1414.3971], dtype=float32)}
# {'predictions': array([1417.7386], dtype=float32)}
# {'predictions': array([5106.6577], dtype=float32)}
# {'predictions': array([1632.8551], dtype=float32)}
# {'predictions': array([1367.4403], dtype=float32)}
# {'predictions': array([5170.7935], dtype=float32)}
# {'predictions': array([3719.6008], dtype=float32)}
# {'predictions': array([1648.7711], dtype=float32)}
# {'predictions': array([1739.2987], dtype=float32)}
# {'predictions': array([2146.5176], dtype=float32)}
# {'predictions': array([2403.12], dtype=float32)}
# {'predictions': array([1564.8654], dtype=float32)}
# {'predictions': array([2307.8635], dtype=float32)}
# {'predictions': array([2678.4531], dtype=float32)}
# {'predictions': array([4942.996], dtype=float32)}
# {'predictions': array([1905.1511], dtype=float32)}
# {'predictions': array([1905.6088], dtype=float32)}
# {'predictions': array([1965.544], dtype=float32)}
# {'predictions': array([1773.9915], dtype=float32)}
# {'predictions': array([3300.934], dtype=float32)}
# {'predictions': array([1410.2559], dtype=float32)}
# {'predictions': array([1870.6528], dtype=float32)}
# {'predictions': array([1831.5228], dtype=float32)}
# {'predictions': array([1301.8661], dtype=float32)}
# {'predictions': array([1198.5186], dtype=float32)}
# {'predictions': array([1079.3558], dtype=float32)}
# {'predictions': array([9502.531], dtype=float32)}
# {'predictions': array([1583.1466], dtype=float32)}
# {'predictions': array([1586.9601], dtype=float32)}
# {'predictions': array([1515.6927], dtype=float32)}
# {'predictions': array([2158.0342], dtype=float32)}
# {'predictions': array([4942.136], dtype=float32)}
# {'predictions': array([1583.1466], dtype=float32)}
# {'predictions': array([1785.5358], dtype=float32)}
# {'predictions': array([2496.5417], dtype=float32)}
# {'predictions': array([1737.7968], dtype=float32)}
# {'predictions': array([1607.4183], dtype=float32)}
# {'predictions': array([1372.6102], dtype=float32)}
# {'predictions': array([6013.083], dtype=float32)}
# {'predictions': array([1821.5594], dtype=float32)}
# {'predictions': array([1345.8295], dtype=float32)}
# {'predictions': array([5106.6577], dtype=float32)}
# {'predictions': array([1375.8496], dtype=float32)}
# {'predictions': array([1297.2826], dtype=float32)}
# {'predictions': array([1649.2562], dtype=float32)}
# {'predictions': array([2125.6611], dtype=float32)}
# {'predictions': array([1620.0487], dtype=float32)}
# {'predictions': array([1330.5422], dtype=float32)}
# {'predictions': array([1789.0994], dtype=float32)}
# {'predictions': array([832.57446], dtype=float32)}
# {'predictions': array([1615.6444], dtype=float32)}
# {'predictions': array([1668.6056], dtype=float32)}
# {'predictions': array([1254.6268], dtype=float32)}
# {'predictions': array([1889.0133], dtype=float32)}
# {'predictions': array([2154.0874], dtype=float32)}
# {'predictions': array([1334.3639], dtype=float32)}
# {'predictions': array([2361.9897], dtype=float32)}
# {'predictions': array([2081.9478], dtype=float32)}
# {'predictions': array([1676.5685], dtype=float32)}
# {'predictions': array([2470.883], dtype=float32)}
# {'predictions': array([1632.8551], dtype=float32)}
# {'predictions': array([1573.2753], dtype=float32)}
# {'predictions': array([1001.144], dtype=float32)}
# {'predictions': array([835.38385], dtype=float32)}
# {'predictions': array([3293.4902], dtype=float32)}
# {'predictions': array([1418.4418], dtype=float32)}
# {'predictions': array([2465.8042], dtype=float32)}
# {'predictions': array([1012.6606], dtype=float32)}
# {'predictions': array([2635.4043], dtype=float32)}
# {'predictions': array([1865.9803], dtype=float32)}
# {'predictions': array([1190.699], dtype=float32)}
# {'predictions': array([1632.8551], dtype=float32)}
# {'predictions': array([3467.1162], dtype=float32)}
# {'predictions': array([1083.8112], dtype=float32)}
# {'predictions': array([932.045], dtype=float32)}
# {'predictions': array([1843.798], dtype=float32)}
# {'predictions': array([1401.8469], dtype=float32)}
# {'predictions': array([1297.2826], dtype=float32)}
# {'predictions': array([1101.4509], dtype=float32)}
# {'predictions': array([1695.3224], dtype=float32)}
# {'predictions': array([1687.0961], dtype=float32)}
# {'predictions': array([1858.6047], dtype=float32)}
# {'predictions': array([1531.9613], dtype=float32)}
# {'predictions': array([1167.2595], dtype=float32)}
# {'predictions': array([2158.0342], dtype=float32)}
# {'predictions': array([1620.0487], dtype=float32)}
# {'predictions': array([1333.375], dtype=float32)}
# {'predictions': array([2388.626], dtype=float32)}
# {'predictions': array([1002.78925], dtype=float32)}
# {'predictions': array([1887.1561], dtype=float32)}
# {'predictions': array([1687.0961], dtype=float32)}
# {'predictions': array([1877.64], dtype=float32)}
# {'predictions': array([2366.5186], dtype=float32)}
# {'predictions': array([1799.9086], dtype=float32)}
# {'predictions': array([1762.526], dtype=float32)}
# {'predictions': array([1991.4609], dtype=float32)}
# {'predictions': array([1676.5172], dtype=float32)}
# {'predictions': array([1472.5109], dtype=float32)}
# {'predictions': array([1429.9583], dtype=float32)}
# {'predictions': array([1561.5751], dtype=float32)}
# {'predictions': array([3076.0635], dtype=float32)}
# {'predictions': array([1578.9183], dtype=float32)}
# {'predictions': array([2663.1658], dtype=float32)}
# {'predictions': array([1961.4027], dtype=float32)}
# {'predictions': array([1316.974], dtype=float32)}
# {'predictions': array([1546.9519], dtype=float32)}
# {'predictions': array([1660.2875], dtype=float32)}
# {'predictions': array([2144.1646], dtype=float32)}
# {'predictions': array([836.6226], dtype=float32)}
# {'predictions': array([1510.7572], dtype=float32)}
# {'predictions': array([1254.9135], dtype=float32)}
# {'predictions': array([1757.212], dtype=float32)}
# {'predictions': array([2635.3123], dtype=float32)}
# {'predictions': array([2569.5999], dtype=float32)}
# {'predictions': array([7575.956], dtype=float32)}
# {'predictions': array([2127.3062], dtype=float32)}
# {'predictions': array([2076.3047], dtype=float32)}
# {'predictions': array([1860.461], dtype=float32)}
# {'predictions': array([1769.3568], dtype=float32)}
# {'predictions': array([1744.1932], dtype=float32)}
# {'predictions': array([1468.3339], dtype=float32)}
# {'predictions': array([1076.5228], dtype=float32)}
# {'predictions': array([932.045], dtype=float32)}
# {'predictions': array([1043.8685], dtype=float32)}
# {'predictions': array([1408.7539], dtype=float32)}
# {'predictions': array([1597.9535], dtype=float32)}
# {'predictions': array([2337.4136], dtype=float32)}
# {'predictions': array([2472.27], dtype=float32)}
# {'predictions': array([1315.7354], dtype=float32)}
# {'predictions': array([2900.4795], dtype=float32)}
# {'predictions': array([1084.9988], dtype=float32)}
# {'predictions': array([1667.76], dtype=float32)}
# {'predictions': array([2335.7173], dtype=float32)}
# {'predictions': array([1297.2826], dtype=float32)}
# {'predictions': array([9502.531], dtype=float32)}
# {'predictions': array([1578.5631], dtype=float32)}
# {'predictions': array([1482.6049], dtype=float32)}
# {'predictions': array([2222.1462], dtype=float32)}
# {'predictions': array([1657.1813], dtype=float32)}
# {'predictions': array([1959.7574], dtype=float32)}
# {'predictions': array([1746.0228], dtype=float32)}
# {'predictions': array([699.76874], dtype=float32)}
# {'predictions': array([1325.2512], dtype=float32)}
# {'predictions': array([1718.0542], dtype=float32)}
# {'predictions': array([1696.9674], dtype=float32)}
# {'predictions': array([1093.6824], dtype=float32)}
# {'predictions': array([1572.3888], dtype=float32)}
# {'predictions': array([1117.2467], dtype=float32)}
# {'predictions': array([1323.305], dtype=float32)}
# {'predictions': array([1655.536], dtype=float32)}
# {'predictions': array([2158.0342], dtype=float32)}
# {'predictions': array([1574.6163], dtype=float32)}
# {'predictions': array([1566.3561], dtype=float32)}
# {'predictions': array([1017.5961], dtype=float32)}
# {'predictions': array([2483.7864], dtype=float32)}
# {'predictions': array([1064.0686], dtype=float32)}
# {'predictions': array([1718.0542], dtype=float32)}
# {'predictions': array([3578.1125], dtype=float32)}
# {'predictions': array([1235.8236], dtype=float32)}
# {'predictions': array([1629.5137], dtype=float32)}
# {'predictions': array([3719.6008], dtype=float32)}
# {'predictions': array([2065.851], dtype=float32)}
# {'predictions': array([1550.2423], dtype=float32)}
# {'predictions': array([1160.0222], dtype=float32)}
# {'predictions': array([3250.1523], dtype=float32)}
# {'predictions': array([1666.6971], dtype=float32)}
# {'predictions': array([2086.8835], dtype=float32)}
# {'predictions': array([2508.058], dtype=float32)}
# {'predictions': array([1566.0187], dtype=float32)}
# {'predictions': array([2076.0352], dtype=float32)}
# {'predictions': array([2149.1003], dtype=float32)}
# {'predictions': array([1697.425], dtype=float32)}
# {'predictions': array([1969.7208], dtype=float32)}
# {'predictions': array([1957.3179], dtype=float32)}
# {'predictions': array([1193.5829], dtype=float32)}
# {'predictions': array([1673.9344], dtype=float32)}
# {'predictions': array([3169.3833], dtype=float32)}
# {'predictions': array([2721.584], dtype=float32)}
# {'predictions': array([1084.9988], dtype=float32)}
# {'predictions': array([1696.9674], dtype=float32)}
# {'predictions': array([1401.8469], dtype=float32)}
# {'predictions': array([1086.394], dtype=float32)}
# {'predictions': array([2098.0989], dtype=float32)}
# {'predictions': array([4614.5586], dtype=float32)}
# {'predictions': array([1661.1791], dtype=float32)}
# {'predictions': array([1437.0746], dtype=float32)}
# {'predictions': array([2079.0637], dtype=float32)}
# {'predictions': array([2635.3123], dtype=float32)}
# {'predictions': array([2030.5017], dtype=float32)}
# {'predictions': array([1512.047], dtype=float32)}
# {'predictions': array([1840.5077], dtype=float32)}
# {'predictions': array([1957.3179], dtype=float32)}
# {'predictions': array([2547.8987], dtype=float32)}
# {'predictions': array([1643.1329], dtype=float32)}
# {'predictions': array([1084.9988], dtype=float32)}
# {'predictions': array([1277.4889], dtype=float32)}
# {'predictions': array([1602.9403], dtype=float32)}
# {'predictions': array([2035.8816], dtype=float32)}
# {'predictions': array([1789.0994], dtype=float32)}
# {'predictions': array([1491.722], dtype=float32)}
# {'predictions': array([1733.6198], dtype=float32)}
# {'predictions': array([1253.778], dtype=float32)}
# {'predictions': array([2943.0635], dtype=float32)}
# {'predictions': array([3624.1313], dtype=float32)}
# {'predictions': array([1331.7809], dtype=float32)}
# {'predictions': array([1611.8226], dtype=float32)}
# {'predictions': array([1604.4423], dtype=float32)}
# {'predictions': array([2413.0422], dtype=float32)}
# {'predictions': array([1140.9872], dtype=float32)}
# {'predictions': array([1667.76], dtype=float32)}
# {'predictions': array([1281.0013], dtype=float32)}
# {'predictions': array([3130.4707], dtype=float32)}
# {'predictions': array([1276.8612], dtype=float32)}
# {'predictions': array([1597.9535], dtype=float32)}
# {'predictions': array([3194.0264], dtype=float32)}
# {'predictions': array([1647.1259], dtype=float32)}
# {'predictions': array([1596.6095], dtype=float32)}
# {'predictions': array([1459.4003], dtype=float32)}
# {'predictions': array([1972.1248], dtype=float32)}
# {'predictions': array([1531.7897], dtype=float32)}
# {'predictions': array([918.8833], dtype=float32)}
# {'predictions': array([1892.447], dtype=float32)}
# {'predictions': array([2152.3909], dtype=float32)}
# {'predictions': array([1616.8094], dtype=float32)}
# {'predictions': array([1437.0746], dtype=float32)}
# {'predictions': array([1732.6769], dtype=float32)}
# {'predictions': array([1295.0511], dtype=float32)}
# {'predictions': array([1634.005], dtype=float32)}
# {'predictions': array([1744.1932], dtype=float32)}
# {'predictions': array([1484.1073], dtype=float32)}
# {'predictions': array([1599.5988], dtype=float32)}
# {'predictions': array([1485.1411], dtype=float32)}
# {'predictions': array([1416.6245], dtype=float32)}
# {'predictions': array([914.8853], dtype=float32)}
# {'predictions': array([999.49884], dtype=float32)}
# {'predictions': array([1519.2843], dtype=float32)}
# {'predictions': array([1012.6606], dtype=float32)}
# {'predictions': array([1818.4635], dtype=float32)}
# {'predictions': array([1763.6216], dtype=float32)}
# {'predictions': array([2109.6152], dtype=float32)}
# {'predictions': array([2518.336], dtype=float32)}

# %%
df_test.head(12)
# Out:
#           State  BuiltUpSize  RentalPerMth  NoOfBedroom        Furnishing  \
# 34273  SELANGOR          790          2300            1   Fully Furnished
# 17565  SELANGOR         1427           900            4  Partly Furnished
# 18809  SELANGOR         1173          1100            4       Unfurnished
# 38620  SELANGOR         2600          1500            4  Partly Furnished
# 41858  SELANGOR         1372          2300            3   Fully Furnished
# 35734  SELANGOR         2300          1800            4  Partly Furnished
# 19205  SELANGOR         1937          1300            4       Unfurnished
# 39838  SELANGOR         1020          1800            3   Fully Furnished
# 20737  SELANGOR         1001          1500            2   Fully Furnished
# 43062  SELANGOR         1916          4900            3   Fully Furnished
# 14317  SELANGOR         1331          3800            3   Fully Furnished
# 52565  SELANGOR         1600          2800            3   Fully Furnished
#
#                    PropertyType
# 34273               CONDOMINIUM
# 17565  2-STY TERRACE/LINK HOUSE
# 18809  2-STY TERRACE/LINK HOUSE
# 38620       SEMI-DETACHED HOUSE
# 41858               CONDOMINIUM
# 35734  2-STY TERRACE/LINK HOUSE
# 19205  2-STY TERRACE/LINK HOUSE
# 39838               CONDOMINIUM
# 20737               CONDOMINIUM
# 43062               CONDOMINIUM
# 14317               CONDOMINIUM
# 52565               CONDOMINIUM
