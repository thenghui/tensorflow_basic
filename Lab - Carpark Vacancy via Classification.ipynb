# %% [markdown]
# # Lab - CarPark Vacancy
# Reference: Dataset was extracted from one of the KlangValley shopping mall (updated to Nov 2018)
#
# Exercise:
# 1. Predict the carpark vacant status in Zone A.

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import seaborn as sns
import shutil
# Out:
# /Users/thenghui/anaconda3/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.5
#   return f(*args, **kwds)

# %% [markdown]
# ## Reading dataset

# %%
df_sep = pd.read_csv("./data/2018-09/vacantBays_2018-9.csv")
print('Sep dataset: {}'.format(df_sep.shape))

df_oct = pd.read_csv("./data/2018-10/vacantBays_2018-10.csv")
#df_oct.dtypes
print('Oct dataset: {}'.format(df_oct.shape))

df_nov = pd.read_csv("./data/2018-11/vacantBays_2018-11.csv")
print('Nov dataset: {}'.format(df_nov.shape))

df = df_sep.append(df_oct.append(df_nov))
print('Sep - Oct dataset: {}'.format(df.shape))
# Out:
# Sep dataset: (1051, 9)
# Oct dataset: (2969, 9)
# Nov dataset: (2871, 9)
# Sep - Oct dataset: (6891, 9)

# %% [markdown]
# ## Cleanup & prepare data

# %%
#Cleanup numbers

cleanup_nums = {"A": {"FULL": 0},
                "B": {"FULL": 0},
                "C": {"FULL": 0},
                "G": {"FULL": 0},
                "H": {"FULL": 0},
                "P": {"FULL": 0},
                "U": {"FULL": 0},
               }

df.replace(cleanup_nums, inplace=True)
df.dropna(subset=['A','B','C','G','H','P','U'])
print(df.shape)
# Out:
# (6891, 9)

# %%
# Convert to datetime

df['A'] = df['A'].astype(np.float64)
df['B'] = df['B'].astype(np.float64)
df['C'] = df['C'].astype(np.float64)
df['G'] = df['G'].astype(np.float64)
df['H'] = df['H'].astype(np.float64)
df['P'] = df['P'].astype(np.float64)
df['U'] = df['U'].astype(np.float64)
df['DateTime'] =  pd.to_datetime(df['DateTime'])
df.dtypes
# Out:
# DateTime      datetime64[ns]
# IsoWeekday             int64
# A                    float64
# B                    float64
# C                    float64
# G                    float64
# H                    float64
# P                    float64
# U                    float64
# dtype: object

# %%
# Extract Hour and Minute
df['Hour'] = df.DateTime.apply(lambda x: x.hour)
df['Minute'] = df.DateTime.apply(lambda x: x.minute)
df.head()
# Out:
#                     DateTime  IsoWeekday      A       B      C       G  \
# 0 2018-09-20 01:32:30.850890           4  770.0  2592.0  875.0  1410.0
# 1 2018-09-20 01:39:01.932373           4  773.0  2590.0  876.0  1415.0
# 2 2018-09-20 01:39:40.024931           4  773.0  2591.0  876.0  1414.0
# 3 2018-09-20 01:39:52.258908           4  773.0  2591.0  876.0  1415.0
# 4 2018-09-20 01:40:49.225890           4  773.0  2590.0  876.0  1412.0
#
#         H      P      U  A_State  Hour  Minute
# 0  1455.0  310.0  811.0        3     1      32
# 1  1459.0  310.0  810.0        3     1      39
# 2  1459.0  310.0  810.0        3     1      39
# 3  1459.0  310.0  810.0        3     1      39
# 4  1458.0  310.0  810.0        3     1      40

# %% [markdown]
# ## Classify the carpark vacant status

# %%
df.describe()
# Out:
#         IsoWeekday            A            B            C            G  \
# count  6891.000000  6857.000000  6856.000000  6857.000000  6853.000000
# mean      4.010013   697.385883  1440.016044   723.302610   772.057931
# std       1.974669   604.831289  1074.659781   667.102289   569.929676
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.000000    63.000000   292.000000    54.000000   183.000000
# 50%       4.000000   739.000000  1592.500000   726.000000   826.000000
# 75%       6.000000  1057.000000  2575.000000  1071.000000  1372.000000
# max       7.000000  1786.000000  2646.000000  1921.000000  1495.000000
#
#                  H            P            U
# count  6851.000000  6855.000000  6855.000000
# mean    779.246679   209.576222   494.911451
# std     588.127668   106.128075   287.413354
# min       0.000000     0.000000     0.000000
# 25%     166.000000   121.000000   233.000000
# 50%     823.000000   254.000000   553.000000
# 75%    1399.000000   305.000000   779.000000
# max    1519.000000   317.000000   831.000000

# %%
# Define status for Carpark Zone A
def A_state(x):
    if x > 1057:
        return 4 # you are early!
    elif x > 739:
        return 3 # plenty of vacancy
    elif x > 63:
        return 2 # limited bay
    elif x > 0:
        return 1 # good luck
    else:
        return 0
    
df['A_State'] = df['A'].apply(A_state)
df.head()
# Out:
#                     DateTime  IsoWeekday      A       B      C       G  \
# 0 2018-09-20 01:32:30.850890           4  770.0  2592.0  875.0  1410.0
# 1 2018-09-20 01:39:01.932373           4  773.0  2590.0  876.0  1415.0
# 2 2018-09-20 01:39:40.024931           4  773.0  2591.0  876.0  1414.0
# 3 2018-09-20 01:39:52.258908           4  773.0  2591.0  876.0  1415.0
# 4 2018-09-20 01:40:49.225890           4  773.0  2590.0  876.0  1412.0
#
#         H      P      U  A_State
# 0  1455.0  310.0  811.0        3
# 1  1459.0  310.0  810.0        3
# 2  1459.0  310.0  810.0        3
# 3  1459.0  310.0  810.0        3
# 4  1458.0  310.0  810.0        3

# %% [markdown]
# ## Split into dataset of: Train, Validation, Test (70%-20%-10%)

# %%
df_train0, df_valid0, df_test0 = np.split(df.sample(frac=1), [int(.7*len(df)), int(.9*len(df))])

# select only Featured columns
df_train = df_train0[['A_State','Hour','Minute','IsoWeekday']]
df_valid = df_valid0[['A_State','Hour','Minute','IsoWeekday']]
df_test = df_test0[['A_State','Hour','Minute','IsoWeekday']]

print('Train set: {}'.format(df_train.shape))
print('Validate set: {}'.format(df_valid.shape))
print('Test set: {}'.format(df_test.shape))
# Out:
# Train set: (4823, 4)
# Validate set: (1378, 4)
# Test set: (690, 4)

# %% [markdown]
# ## Feature & Label

# %%
FEATURES_NUM = ['Hour','Minute','IsoWeekday']
LABEL = 'A_State'

# %% [markdown]
# ## Determine metrics for validation - Accuracy

# %%
def print_accuracy(model, df):
  metrics = model.evaluate(input_fn = tf.estimator.inputs.pandas_input_fn(
    x = df,
    y = df[LABEL],
    batch_size = 128,
    shuffle = False
  ))
  print('Accuracy on dataset = {}'.format(metrics['accuracy']))
    
#print_accuracy(model, df_valid)

# %% [markdown]
# ## Model: DNN Classifier

# %%
# DNNClassifier
OUTDIR = 'carparkClass_trained'
tf.logging.set_verbosity(tf.logging.INFO)
shutil.rmtree(OUTDIR, ignore_errors = True) # start fresh each time

model = tf.estimator.DNNClassifier(
    hidden_units = [512, 256, 128], 
    feature_columns = [tf.feature_column.numeric_column('Hour'),
                       tf.feature_column.numeric_column('Minute'),
                       tf.feature_column.numeric_column('IsoWeekday')
                      ], 
    activation_fn = tf.nn.relu,
    n_classes=5,
    optimizer=tf.train.AdamOptimizer(
      learning_rate=0.01,
      #l1_regularization_strength=0.001
    ),
    #loss_reduction='weighted_sum',
    model_dir = OUTDIR,
#    config=tf.estimator.RunConfig(save_summary_steps=2,
#                                  save_checkpoints_steps=2)
)

model.train(input_fn = tf.estimator.inputs.pandas_input_fn(
    x = df_train,
    y = df_train[LABEL],
    batch_size = 128,
    num_epochs = 50,
    shuffle = True
  ));

print_accuracy(model, df_valid)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1884: carparkClass_trained/model.ckpt-1884
# Accuracy on dataset = 0.78447026014328

# %% [markdown]
# ## Prediction

# %%
predictions = model.predict(input_fn = tf.estimator.inputs.pandas_input_fn(
#    x = pd.DataFrame({
#                      'Hour':[9,10,12],
#                      'Minute':[0,0,0],
#                      'IsoWeekday':[4,4,5]}),
    x = df_test,
    y = None,
    batch_size = 64,
    shuffle = False
  ))

for items in predictions:
  print(items)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from carparkClass_trained/model.ckpt-1884
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# {'logits': array([-16.245052 , -14.926212 ,   2.6889298,   4.157054 ,   9.885626 ],
#       dtype=float32), 'probabilities': array([4.4653612e-12, 1.6696349e-11, 7.4607151e-04, 3.2387599e-03,
#        9.9601513e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-3.5690308,  2.561318 ,  4.062757 , -0.5455971, -4.222418 ],
#       dtype=float32), 'probabilities': array([3.9301801e-04, 1.8062966e-01, 8.1069177e-01, 8.0811474e-03,
#        2.0447954e-04], dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-4.938882  , -2.2040906 ,  1.9009812 , -0.88653386, -1.0794947 ],
#       dtype=float32), 'probabilities': array([0.00094721, 0.01459316, 0.8850328 , 0.05449503, 0.04493193],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-12.208609 , -11.267619 ,   2.3610287,   4.4264297,   0.7283354],
#       dtype=float32), 'probabilities': array([5.1786461e-08, 1.3270362e-07, 1.1008529e-01, 8.6840355e-01,
#        2.1510951e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-1.5446352,  3.3703642,  3.5973141, -1.3911821, -4.559837 ],
#       dtype=float32), 'probabilities': array([3.2301522e-03, 4.4033179e-01, 5.5251378e-01, 3.7658818e-03,
#        1.5839349e-04], dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-1.0864925 , -6.3818307 ,  0.70601016,  3.3703709 , -0.22382087],
#       dtype=float32), 'probabilities': array([1.0460731e-02, 5.2459734e-05, 6.2811047e-02, 9.0188926e-01,
#        2.4786519e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ -0.9232848, -13.392339 ,  -1.0088749,   6.252513 ,   0.4898255],
#       dtype=float32), 'probabilities': array([7.6136558e-04, 2.9265232e-09, 6.9891126e-04, 9.9541157e-01,
#        3.1282338e-03], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-19.406109 , -13.5364895,   1.495033 ,   4.611074 ,   8.675595 ],
#       dtype=float32), 'probabilities': array([6.2596824e-13, 2.2166380e-10, 7.4782950e-04, 1.6868711e-02,
#        9.8238349e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-3.2770977,  0.9270004,  2.8733811,  0.4973793, -2.0757933],
#       dtype=float32), 'probabilities': array([0.00171291, 0.11469688, 0.8032561 , 0.07463964, 0.00569449],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-2.7528405 , -6.322416  ,  2.5314717 ,  3.090812  ,  0.66693497],
#       dtype=float32), 'probabilities': array([1.7426260e-03, 4.9085964e-05, 3.4367818e-01, 6.0127109e-01,
#        5.3259112e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-5.1713533, -5.4376593,  2.8289788,  3.8439636, -1.2689122],
#       dtype=float32), 'probabilities': array([8.8798974e-05, 6.8038185e-05, 2.6479393e-01, 7.3065162e-01,
#        4.3976083e-03], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-23.788082 , -15.132273 ,   1.7368724,   3.9918582,  13.565991 ],
#       dtype=float32), 'probabilities': array([5.9882377e-17, 3.4392877e-13, 7.2886260e-06, 6.9498201e-05,
#        9.9992323e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-5.654396 , -5.297174 ,  1.3620946,  1.9899162,  1.1245944],
#       dtype=float32), 'probabilities': array([2.4478548e-04, 3.4988488e-04, 2.7290335e-01, 5.1129121e-01,
#        2.1521071e-01], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-2
-02], dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ -0.9942319 , -13.751237  ,  -0.8183153 ,   6.3551135 ,
#          0.38902664], dtype=float32), 'probabilities': array([6.4046809e-04, 1.8458683e-09, 7.6365453e-04, 9.9604177e-01,
#        2.5541061e-03], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ -0.44310537, -15.070695  ,   0.04777145,   3.524563  ,
#          7.2329683 ], dtype=float32), 'probabilities': array([4.5215475e-04, 2.0072692e-10, 7.3870685e-04, 2.3901412e-02,
#        9.7490770e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ -1.7507302, -10.4669895,   1.4337189,   3.7350686,   3.665635 ],
#       dtype=float32), 'probabilities': array([2.0347727e-03, 3.3349758e-07, 4.9147859e-02, 4.9087179e-01,
#        4.5794520e-01], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-2.9572558, -5.6769705,  3.2506578,  5.5907884, -3.4417183],
#       dtype=float32), 'probabilities': array([1.76834510e-04, 1.16522488e-05, 8.78273249e-02, 9.11875308e-01,
#        1.08935026e-04], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 2.2092576,  3.4087324,  1.0102473, -3.5228465, -1.5208857],
#       dtype=float32), 'probabilities': array([2.1518816e-01, 7.1407473e-01, 6.4877599e-02, 6.9726410e-04,
#        5.1622358e-03], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-1.7627909 , -0.23250508,  3.146473  , -1.0228367 , -1.8753115 ],
#       dtype=float32), 'probabilities': array([0.00693729, 0.03204679, 0.9402775 , 0.01453945, 0.00619902],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 0.07881835,  1.9306026 ,  2.0485036 , -2.3641357 , -1.7395073 ],
#       dtype=float32), 'probabilities': array([0.06761875, 0.430811  , 0.4847196 , 0.00587632, 0.01097434],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-1.560596  , -4.08014   , -0.14607728,  0.11118914,  4.219573  ],
#       dtype=float32), 'probabilities': array([2.9910516e-03, 2.4076857e-04, 1.2306700e-02, 1.5917361e-02,
#        9.6854413e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-9.205608  , -8.593818  ,  2.6035447 ,  0.53789616, -0.76406837],
#       dtype=float32), 'probabilities': array([6.4037199e-06, 1.1806718e-05, 8.6115658e-01, 1.0913961e-01,
#        2.9685635e-02], dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-1.4245231 , -5.337177  ,  0.17476416,  3.7137249 ,  0.46583927],
#       dtype=float32), 'probabilities': array([5.4642367e-03, 1.0921585e-04, 2.7045257e-02, 9.3119842e-01,
#        3.6182903e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-16.48132  , -15.160753 ,   3.0535483,   4.4509106,   9.4552965],
#       dtype=float32), 'probabilities': array([5.3982448e-12, 2.0219312e-11, 1.6448923e-03, 6.6527952e-03,
#        9.9170238e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-17.722437 , -15.417293 ,   2.3639808,   4.2578173,   9.941766 ],
#       dtype=float32), 'probabilities': array([9.6359249e-13, 9.6606265e-12, 5.0969952e-04, 3.3868577e-03,
#        9.9610341e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 1.9874578,  2.5856988,  0.4795062, -3.6165664, -1.1743153],
#       dtype=float32), 'probabilities': array([0.3240112 , 0.5893494 , 0.07172409, 0.00119334, 0.01372207],
#       dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-11.936016, -12.106132,   2.530785,   4.264186,   8.070205],
#       dtype=float32), 'probabilities': array([1.9961397e-09, 1.6838800e-09, 3.8286287e-03, 2.1669539e-02,
#        9.7450179e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-18.25881  , -17.05372  ,   1.322521 ,   2.2250266,  16.365864 ],
#       dtype=float32), 'probabilities': array([9.1768915e-16, 3.0623699e-15, 2.9292664e-07, 7.2229096e-07,
#        9.9999893e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-6.480188 , -5.5064588,  2.1785502, -1.0263586, -0.9324387],
#       dtype=float32), 'probabilities': array([1.5989205e-04, 4.2336219e-04, 9.2102003e-01, 3.7358966e-02,
#        4.1037772e-02], dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-3.3806906, -3.4929214,  3.1296287,  1.7156581, -1.0922378],
#       dtype=float32), 'probabilities': array([0.00118033, 0.00105503, 0.7932321 , 0.19289486, 0.01163769],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ -0.9179128 , -15.4054985 ,  -1.0836277 ,   6.3948326 ,
#          0.96788526], dtype=float32), 'probabilities': array([6.6325016e-04, 3.3868730e-10, 5.6196383e-04, 9.9440295e-01,
#        4.3718880e-03], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 3.4575033 ,  2.7195027 , -0.65286595, -5.0720534 ,  0.01126528],
#       dtype=float32), 'probabilities': array([6.5507901e-01, 3.1317285e-01, 1.0744421e-02, 1.2940601e-04,
#        2.0874280e-02], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([-4.5831814e-01, -1.4959315e+01, -9.3263984e-03,  3.4354784e+00,
#         7.2504234e+00], dtype=float32), 'probabilities': array([4.3871175e-04, 2.2104253e-10, 6.8734371e-04, 2.1539405e-02,
#        9.7733456e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 3.9325984 ,  3.960948  ,  0.08449861, -4.4776664 , -1.0883673 ],
#       dtype=float32), 'probabilities': array([4.8616937e-01, 5.0014931e-01, 1.0365235e-02, 1.0820722e-04,
#        3.2078188e-03], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-17.726887 , -14.539151 ,   2.4931946,   3.2836487,  11.668121 ],
#       dtype=float32), 'probabilities': array([1.71303428e-13, 4.15128348e-12, 1.03570426e-04, 2.28310324e-04,
#        9.99668121e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-7.900235 , -7.767197 ,  2.908633 , -2.7578952, 12.946363 ],
#       dtype=float32), 'probabilities': array([8.8392982e-10, 1.0097087e-09, 4.3716977e-05, 1.5125438e-07,
#        9.9995613e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-2.96898   , -8.184782  ,  1.4967794 ,  3.3410368 ,  0.18630111],
#       dtype=float32), 'probabilities': array([1.5117017e-03, 8.2086544e-06, 1.3149847e-01, 8.3151770e-01,
#        3.5463963e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 3.9560802 ,  3.8569424 , -0.22716117, -4.6079226 , -0.70079666],
#       dtype=float32), 'probabilities': array([5.1798606e-01, 4.6909747e-01, 7.8987693e-03, 9.8859600e-05,
#        4.9188333e-03], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([ -1.5454543 , -13.952995  ,  -0.46403915,   6.677664  ,
#         -0.03226662], dtype=float32), 'probabilities': array([2.6776688e-04, 1.0945362e-09, 7.8960398e-04, 9.9772662e-01,
#        1.2159783e-03], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-2.309817 , -7.8386464,  2.3374681,  3.0838683,  1.5788355],
#       dtype=float32), 'probabilities': array([2.6726308e-03, 1.0612038e-05, 2.7875924e-01, 5.8801275e-01,
#        1.3054472e-01], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-22.44627  , -13.461272 ,   1.6255949,   5.0121675,  10.747464 ],
#       dtype=float32), 'probabilities': array([3.8255777e-15, 3.0537368e-11, 1.0888669e-04, 3.2191742e-03,
#        9.9667192e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-2.7457757 , -7.878987  ,  0.18052226,  3.2647803 ,  0.9105799 ],
#       dtype=float32), 'probabilities': array([2.1454887e-03, 1.2653216e-05, 4.0031452e-02, 8.7473720e-01,
#        8.3073288e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 1.8419437 ,  1.9919059 ,  0.17564005, -4.2422523 , -0.9584924 ],
#       dtype=float32), 'probabilities': array([0.41428515, 0.48131245, 0.07827677, 0.00094399, 0.02518172],
#       dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-3.249753  , -4.803725  ,  2.8700767 ,  2.6169078 , -0.35526574],
#       dtype=float32), 'probabilities': array([1.2089838e-03, 2.5558719e-04, 5.4983038e-01, 4.2685354e-01,
#        2.1851456e-02], dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 3.7246118 ,  3.7637658 , -0.02503732, -4.4466767 , -0.7888962 ],
#       dtype=float32), 'probabilities': array([4.8199758e-01, 5.0124407e-01, 1.1339476e-02, 1.3623835e-04,
#        5.2826675e-03], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-2.7174215, -2.0546217,  2.0567799, -2.7578237, -1.8722248],
#       dtype=float32), 'probabilities': array([0.0080228 , 0.01556597, 0.95002556, 0.00770512, 0.01868057],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-12.980961 , -10.613559 ,   1.6597087,  -1.4515494,  18.491951 ],
#       dtype=float32), 'probabilities': array([2.1453002e-14, 2.2889552e-13, 4.8960942e-08, 2.1809603e-09,
#        1.0000000e+00], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-1.0439124 , -7.1730714 ,  0.559204  ,  3.684225  , -0.23164284],
#       dtype=float32), 'probabilities': array([8.2434509e-03, 1.7957644e-05, 4.0957529e-02, 9.3220854e-01,
#        1.8572625e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-7.8221526 , -6.8486133 ,  2.6131706 ,  5.345667  ,  0.16169196],
#       dtype=float32), 'probabilities': array([1.7849787e-06, 4.7253698e-06, 6.0762629e-02, 9.3399513e-01,
#        5.2356785e-03], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 4.5717335 ,  3.8754153 ,  0.35591835, -5.3558655 , -1.9806391 ],
#       dtype=float32), 'probabilities': array([6.6021734e-01, 3.2906356e-01, 9.7449971e-03, 3.2224449e-05,
#        9.4194972e-04], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([ -0.42894295, -16.382948  ,  -0.32317144,   4.0058646 ,
#          8.231475  ], dtype=float32), 'probabilities': array([1.7075361e-04, 2.0120275e-11, 1.8980417e-04, 1.4400656e-02,
#        9.8523879e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 3.9088197 ,  3.6984284 , -0.47478908, -4.6808953 , -0.5091572 ],
#       dtype=float32), 'probabilities': array([5.4496151e-01, 4.4156441e-01, 6.8012495e-03, 1.0136780e-04,
#        6.5714754e-03], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([-1.0339601 ,  0.85576385,  2.5375102 , -1.3713801 , -1.7570168 ],
#       dtype=float32), 'probabilities': array([0.02253   , 0.14909321, 0.8013661 , 0.01607761, 0.01093306],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-2.33398  , -8.186875 ,  2.4132638,  3.205679 ,  1.6045709],
#       dtype=float32), 'probabilities': array([2.3685214e-03, 6.8013828e-06, 2.7301037e-01, 6.0300463e-01,
#        1.2160971e-01], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-3.5782452 ,  0.8569844 ,  3.171644  , -0.16050957, -2.3642344 ],
#       dtype=float32), 'probabilities': array([0.00102753, 0.08669467, 0.87747806, 0.0313401 , 0.00345967],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-5.6000714 , -5.1837816 ,  1.7973433 , -2.3964608 , -0.51018983],
#       dtype=float32), 'probabilities': array([5.4906786e-04, 8.3256542e-04, 8.9594716e-01, 1.3518751e-02,
#        8.9152500e-02], dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-20.245825 , -16.7348   ,   1.6875341,   1.8863113,  16.49572  ],
#       dtype=float32), 'probabilities': array([1.1049654e-16, 3.6997065e-15, 3.7058373e-07, 4.5207887e-07,
#        9.9999917e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-1.0106558 , -0.01219505,  2.8586154 , -0.8550062 , -4.8878365 ],
#       dtype=float32), 'probabilities': array([1.8935561e-02, 5.1393025e-02, 9.0715468e-01, 2.2124628e-02,
#        3.9213902e-04], dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-2
-03], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 3.9480042,  3.9178696,  0.5314406, -4.7731404, -1.8413942],
#       dtype=float32), 'probabilities': array([4.9841431e-01, 4.8361880e-01, 1.6360473e-02, 8.1291568e-05,
#        1.5250596e-03], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([-4.8474317 , -6.531285  ,  2.245374  ,  3.0061896 , -0.06428313],
#       dtype=float32), 'probabilities': array([2.5647681e-04, 4.7616777e-05, 3.0861327e-01, 6.6043884e-01,
#        3.0643845e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 0.07326743,  0.34420103,  0.8850996 , -3.869537  , -1.4795213 ],
#       dtype=float32), 'probabilities': array([0.20858239, 0.27349073, 0.46973386, 0.00404519, 0.0441479 ],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 3.5810878 ,  3.1197407 , -0.40409   , -4.8464885 , -0.39966488],
#       dtype=float32), 'probabilities': array([5.99551558e-01, 3.77977580e-01, 1.11451475e-02, 1.31152556e-04,
#        1.11945746e-02], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([-6.675229  , -6.313733  ,  2.077443  , -1.9563558 , -0.28320366],
#       dtype=float32), 'probabilities': array([1.4206329e-04, 2.0392833e-04, 8.9891595e-01, 1.5917050e-02,
#        8.4820993e-02], dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 4.5717335 ,  3.8754153 ,  0.35591835, -5.3558655 , -1.9806391 ],
#       dtype=float32), 'probabilities': array([6.6021734e-01, 3.2906356e-01, 9.7449971e-03, 3.2224449e-05,
#        9.4194972e-04], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([-12.651388 , -12.456923 ,   1.2083621,   2.9794788,  12.570064 ],
#       dtype=float32), 'probabilities': array([1.1128288e-11, 1.3517105e-11, 1.1631636e-05, 6.8363959e-05,
#        9.9992001e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 3.6622148 ,  3.78854   , -0.04019305, -4.3608274 , -0.81140995],
#       dtype=float32), 'probabilities': array([4.60606873e-01, 5.22628069e-01, 1.13604395e-02, 1.50996697e-04,
#        5.25363488e-03], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-7.726447 , -6.2331862,  2.4095507, -0.5278959, -1.1163568],
#       dtype=float32), 'probabilities': array([3.6602203e-05, 1.6293800e-04, 9.2366630e-01, 4.8955135e-02,
#        2.7178966e-02], dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ -1.3781136, -11.474706 ,   1.2368505,   3.3450696,   4.3719864],
#       dtype=float32), 'probabilities': array([2.2654426e-03, 9.3381097e-08, 3.0961191e-02, 2.5492099e-01,
#        7.1185225e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-2.940894  , -0.69603616,  1.9436262 ,  0.11088373, -0.21473312],
#       dtype=float32), 'probabilities': array([0.00558369, 0.05270484, 0.7383142 , 0.11811126, 0.08528599],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 2.1461377,  3.496586 ,  2.1755996, -3.6181774, -3.598095 ],
#       dtype=float32), 'probabilities': array([1.6962393e-01, 6.5460515e-01, 1.7469572e-01, 5.3220260e-04,
#        5.4299855e-04], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-18.344168  , -16.370955  ,   2.0606136 ,   0.23631485,
#         18.216457  ], dtype=float32), 'probabilities': array([1.3241069e-16, 9.5252995e-16, 9.6295537e-08, 1.5535429e-08,
#        9.9999988e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-2.6382854, -8.03751  ,  2.3855944,  3.8362563,  1.5831082],
#       dtype=float32), 'probabilities': array([1.1500139e-03, 5.1981610e-06, 1.7480198e-01, 7.4569422e-01,
#        7.8348555e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-0.42437175, -8.750588  , -0.42249566,  3.389852  ,  0.95846426],
#       dtype=float32), 'probabilities': array([1.9481840e-02, 4.7162866e-06, 1.9518424e-02, 8.8333672e-01,
#        7.7658311e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-3

#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ -1.4752588, -12.351542 ,  -0.7624416,   4.435095 ,   1.6536479],
#       dtype=float32), 'probabilities': array([2.5334076e-03, 4.7884562e-08, 5.1674661e-03, 9.3441337e-01,
#        5.7885792e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-1.8633842,  3.3667185,  3.8056703, -1.0666212, -5.093509 ],
#       dtype=float32), 'probabilities': array([2.0840699e-03, 3.8932928e-01, 6.0388100e-01, 4.6231928e-03,
#        8.2430284e-05], dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-3.5690308,  2.561318 ,  4.062757 , -0.5455971, -4.222418 ],
#       dtype=float32), 'probabilities': array([3.9301801e-04, 1.8062966e-01, 8.1069177e-01, 8.0811474e-03,
#        2.0447954e-04], dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 2.6148489,  3.6180797,  1.0896957, -4.0634575, -1.8993189],
#       dtype=float32), 'probabilities': array([2.5272459e-01, 6.8919975e-01, 5.4989766e-02, 3.1790393e-04,
#        2.7680201e-03], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-14.714535 , -12.475091 ,   1.6660666,   4.4062653,   7.491946 ],
#       dtype=float32), 'probabilities': array([2.1638007e-10, 2.0314013e-09, 2.8133416e-03, 4.3578833e-02,
#        9.5360786e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 3.6622148 ,  3.78854   , -0.04019305, -4.3608274 , -0.81140995],
#       dtype=float32), 'probabilities': array([4.60606873e-01, 5.22628069e-01, 1.13604395e-02, 1.50996697e-04,
#        5.25363488e-03], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([ 4.018477  ,  3.832168  , -0.21200544, -4.6937723 , -0.67828286],
#       dtype=float32), 'probabilities': array([5.3941745e-01, 4.4772577e-01, 7.8460267e-03, 8.8765257e-05,
#        4.9220743e-03], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([ 4.2405334,  3.3298938, -0.7354173, -5.4813967, -0.1960963],
#       dtype=float32), 'probabilities': array([7.0369774e-01, 2.8307429e-01, 4.8568891e-03, 4.2189637e-05,
#        8.3287982e-03], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([-2.6382854, -8.03751  ,  2.3855944,  3.8362563,  1.5831082],
#       dtype=float32), 'probabilities': array([1.1500139e-03, 5.1981610e-06, 1.7480198e-01, 7.4569422e-01,
#        7.8348555e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-3.0784185, -2.8502228,  3.3565629,  0.9050945, -1.3477694],
#       dtype=float32), 'probabilities': array([0.00146012, 0.00183439, 0.910048  , 0.07841607, 0.00824136],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-1.9194632,  3.3439448,  3.7752044, -1.3093185, -4.7587733],
#       dtype=float32), 'probabilities': array([2.0270993e-03, 3.9151114e-01, 6.0261202e-01, 3.7312764e-03,
#        1.1851639e-04], dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ 2.4477687,  3.528216 ,  0.8956169, -3.776819 , -1.4975088],
#       dtype=float32), 'probabilities': array([2.3928513e-01, 7.0493323e-01, 5.0678626e-02, 4.7381819e-04,
#        4.6291752e-03], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([ 0.07881835,  1.9306026 ,  2.0485036 , -2.3641357 , -1.7395073 ],
#       dtype=float32), 'probabilities': array([0.06761875, 0.430811  , 0.4847196 , 0.00587632, 0.01097434],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-6.4800014 , -6.3879476 ,  2.5403306 ,  5.357483  , -0.07903314],
#       dtype=float32), 'probabilities': array([6.7927367e-06, 7.4477221e-06, 5.6172688e-02, 9.3972093e-01,
#        4.0921364e-03], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 3.9096458,  3.8164437,  2.0422122, -2.7081532, -6.322685 ],
#       dtype=float32), 'probabilities': array([4.8381600e-01, 4.4076091e-01, 7.4759111e-02, 6.4655684e-04,
#        1.7411478e-05], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([-13.716036 ,  -6.477796 ,   3.3796358,   1.4454943,   9.529494 ],
#       dtype=float32), 'probabilities': array([8.0082121e-11, 1.1144560e-07, 2.1285850e-03, 3.0768348e-04,
#        9.9756360e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# ...
#       dtype=float32), 'probabilities': array([4.1088220e-03, 6.0795865e-06, 7.0964936e-03, 8.8836175e-01,
#        1.0042687e-01], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-6.471571 , -5.677769 ,  2.420601 , -1.9834819, -1.3827207],
#       dtype=float32), 'probabilities': array([1.3281681e-04, 2.9376292e-04, 9.6621591e-01, 1.1814227e-02,
#        2.1543318e-02], dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-16.938353 , -14.923641 ,   3.1628838,  -1.264793 ,  17.981659 ],
#       dtype=float32), 'probabilities': array([6.8301571e-16, 5.1216465e-15, 3.6668027e-07, 4.3789683e-09,
#        9.9999964e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ -0.9179128 , -15.4054985 ,  -1.0836277 ,   6.3948326 ,
#          0.96788526], dtype=float32), 'probabilities': array([6.6325016e-04, 3.3868730e-10, 5.6196383e-04, 9.9440295e-01,
#        4.3718880e-03], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-19.619999  , -15.199829  ,   1.869288  ,  -0.64915496,
#         19.37946   ], dtype=float32), 'probabilities': array([1.15544815e-17, 9.60297558e-16, 2.48558703e-08, 2.00301153e-09,
#        1.00000000e+00], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-2.9916258 , -0.64860886,  1.9197755 ,  0.2615533 , -0.17920864],
#       dtype=float32), 'probabilities': array([0.00526968, 0.0548711 , 0.7157788 , 0.13633962, 0.08774079],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-7.900235 , -7.767197 ,  2.908633 , -2.7578952, 12.946363 ],
#       dtype=float32), 'probabilities': array([8.8392982e-10, 1.0097087e-09, 4.3716977e-05, 1.5125438e-07,
#        9.9995613e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-2.314879 , -8.796823 , -0.7908183,  3.746637 ,  1.4301584],
#       dtype=float32), 'probabilities': array([2.0967515e-03, 3.2097737e-06, 9.6258242e-03, 8.9955938e-01,
#        8.8714764e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-10.43362   ,  -8.529918  ,   2.9893525 ,   5.6538234 ,
#          0.39531183], dtype=float32), 'probabilities': array([9.5932975e-08, 6.4377770e-07, 6.4787492e-02, 9.3037105e-01,
#        4.8407605e-03], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-2.0032387 , -7.562385  , -0.11047351,  4.0777183 , -0.37425664],
#       dtype=float32), 'probabilities': array([2.2212951e-03, 8.5565689e-06, 1.4744284e-02, 9.7170019e-01,
#        1.1325677e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-3.8945477, -8.830984 , -1.1894529,  4.1616735,  1.4976442],
#       dtype=float32), 'probabilities': array([2.9507244e-04, 2.1186609e-06, 4.4130227e-03, 9.3046695e-01,
#        6.4822793e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-14.24942   , -10.640178  ,   0.16633159,   3.6161902 ,
#          5.8793435 ], dtype=float32), 'probabilities': array([1.6364933e-09, 6.0448826e-08, 2.9826036e-03, 9.3939885e-02,
#        9.0307748e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-3.206223  , -9.519965  ,  1.1927869 ,  3.6241095 ,  0.60432065],
#       dtype=float32), 'probabilities': array([9.4962626e-04, 1.7200043e-06, 7.7271357e-02, 8.7887788e-01,
#        4.2899374e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-14.877333 , -12.998826 ,   3.1955683,   4.470849 ,   9.056226 ],
#       dtype=float32), 'probabilities': array([3.9825081e-11, 2.6060465e-10, 2.8126659e-03, 1.0068520e-02,
#        9.8711884e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-2.9972558 , -5.1523976 ,  2.9310317 ,  2.3258584 , -0.25469613],
#       dtype=float32), 'probabilities': array([1.6745515e-03, 1.9405833e-04, 6.2881237e-01, 3.4331885e-01,
#        2.6000222e-02], dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-2.2797775 , -2.3114064 ,  0.80895096,  0.14108111,  2.0474222 ],
#       dtype=float32), 'probabilities': array([0.00901669, 0.00873596, 0.19790867, 0.10148752, 0.68285114],
#       dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-3.6342833 ,  0.9924146 ,  3.0985365 ,  0.06389882, -2.3404288 ],
#       dtype=float32), 'probabilities': array([0.00101347, 0.10355251, 0.85082024, 0.04091772, 0.00369594],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([ -0.38074175, -16.007523  ,  -0.1660803 ,   4.0338817 ,
#          7.855427  ], dtype=float32), 'probabilities': array([2.5907138e-04, 4.2344295e-11, 3.2110407e-04, 2.1412442e-02,
#        9.7800738e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ -6.4371724 , -10.3173685 ,  -0.01878315,   3.307202  ,
#          0.7219831 ], dtype=float32), 'probabilities': array([5.2748583e-05, 1.0890876e-06, 3.2335661e-02, 8.9978504e-01,
#        6.7825422e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-1.5480742, -9.679735 , -1.2049215,  3.853871 ,  1.8148358],
#       dtype=float32), 'probabilities': array([3.95069132e-03, 1.16181616e-06, 5.56803960e-03, 8.76411438e-01,
#        1.14068635e-01], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-4.540985 , -1.6645265,  2.1069987, -0.5012158, -1.5859249],
#       dtype=float32), 'probabilities': array([0.00115474, 0.02049815, 0.8905682 , 0.06560456, 0.02217435],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-2.0578184, -8.821451 ,  1.8684032,  3.255023 ,  2.4903157],
#       dtype=float32), 'probabilities': array([2.8645240e-03, 3.3085987e-06, 1.4527433e-01, 5.8128643e-01,
#        2.7057147e-01], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-19.598505 , -13.972275 ,   1.7163002,   5.022498 ,   8.808768 ],
#       dtype=float32), 'probabilities': array([4.4955795e-13, 1.2480315e-10, 8.1224582e-04, 2.2159046e-02,
#        9.7702867e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 3.9325984 ,  3.960948  ,  0.08449864, -4.4776664 , -1.0883673 ],
#       dtype=float32), 'probabilities': array([4.8616937e-01, 5.0014931e-01, 1.0365235e-02, 1.0820722e-04,
#        3.2078188e-03], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-7.900235 , -7.767197 ,  2.908633 , -2.7578952, 12.946363 ],
#       dtype=float32), 'probabilities': array([8.8392982e-10, 1.0097087e-09, 4.3716977e-05, 1.5125438e-07,
#        9.9995613e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 1.1961535,  2.7792401,  1.4240324, -2.842701 , -1.5827127],
#       dtype=float32), 'probabilities': array([0.13878047, 0.675856  , 0.17429903, 0.00244498, 0.0086195 ],
#       dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-10.539177 ,  -7.8404613,   1.0171447,  -4.8822937,  21.357422 ],
#       dtype=float32), 'probabilities': array([1.4043752e-14, 2.0869894e-13, 1.4666621e-09, 4.0200950e-12,
#        1.0000000e+00], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 3.3901017,  4.4220567,  2.1274793, -2.6804376, -5.8285813],
#       dtype=float32), 'probabilities': array([2.4438721e-01, 6.8588424e-01, 6.9139868e-02, 5.6451664e-04,
#        2.4235685e-05], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-2.2797775 , -2.3114064 ,  0.80895096,  0.14108111,  2.0474222 ],
#       dtype=float32), 'probabilities': array([0.00901669, 0.00873596, 0.19790867, 0.10148752, 0.68285114],
#       dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-4.5831814e-01, -1.4959315e+01, -9.3263984e-03,  3.4354784e+00,
#         7.2504234e+00], dtype=float32), 'probabilities': array([4.3871175e-04, 2.2104253e-10, 6.8734371e-04, 2.1539405e-02,
#        9.7733456e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-1.8871856, -9.756164 ,  1.6593413,  3.5605388,  3.1188145],
#       dtype=float32), 'probabilities': array([2.3967689e-03, 9.1658472e-07, 8.3150178e-02, 5.5659944e-01,
#        3.5785273e-01], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 1.479921 ,  2.4593194,  2.378137 , -2.9543335, -4.592228 ],
#       dtype=float32), 'probabilities': array([1.6307247e-01, 4.3423811e-01, 4.0037864e-01, 1.9346764e-03,
#        3.7607976e-04], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([-6.7881966, -7.422992 ,  0.7414753,  3.626191 ,  5.5000196],
#       dtype=float32), 'probabilities': array([3.9631896e-06, 2.1006629e-06, 7.3814127e-03, 1.3211608e-01,
#        8.6049646e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ 3.9088197 ,  3.6984284 , -0.47478908, -4.6808953 , -0.5091572 ],
#       dtype=float32), 'probabilities': array([5.4496151e-01, 4.4156441e-01, 6.8012495e-03, 1.0136780e-04,
#        6.5714754e-03], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([-1.437562 , -9.814473 ,  1.2826979,  2.592825 ,  3.7099748],
#       dtype=float32), 'probabilities': array([4.0904069e-03, 9.4128251e-07, 6.2109832e-02, 2.3021908e-01,
#        7.0357972e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ -1.3027794 , -11.531486  ,   0.99558353,   3.1863024 ,
#          4.6419425 ], dtype=float32), 'probabilities': array([2.0758477e-03, 7.4976505e-08, 2.0671023e-02, 1.8483283e-01,
#        7.9242021e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ -1.0955468 , -16.4566    ,  -0.43485445,   7.1213465 ,
#          0.24618506], dtype=float32), 'probabilities': array([2.6956052e-04, 5.7469311e-11, 5.2190479e-04, 9.9817729e-01,
#        1.0312480e-03], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 2.8441114 ,  3.5668426 ,  0.62719184, -3.7028785 , -1.335253  ],
#       dtype=float32), 'probabilities': array([3.1389892e-01, 6.4664805e-01, 3.4197461e-02, 4.5026507e-04,
#        4.8052371e-03], dtype=float32), 'class_ids': array([1]), 'classes': array([b'1'], dtype=object)}
# {'logits': array([ 2.7360737,  2.5581646,  2.3930807, -2.074677 , -6.3168273],
#       dtype=float32), 'probabilities': array([3.9140162e-01, 3.2761040e-01, 2.7775547e-01, 3.1866913e-03,
#        4.5813929e-05], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([-1.0864927 , -6.3818307 ,  0.70601016,  3.3703706 , -0.2238208 ],
#       dtype=float32), 'probabilities': array([1.0460731e-02, 5.2459734e-05, 6.2811062e-02, 9.0188926e-01,
#        2.4786526e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 3.883914  ,  3.7892368 ,  0.06224447, -4.622601  , -0.9704958 ],
#       dtype=float32), 'probabilities': array([5.1558250e-01, 4.6900815e-01, 1.1286731e-02, 1.0422344e-04,
#        4.0184152e-03], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([-4.2574396, -3.5827508,  1.693681 , -2.7821028, -0.6694784],
#       dtype=float32), 'probabilities': array([0.0023382 , 0.00459087, 0.89829725, 0.01022379, 0.08454987],
#       dtype=float32), 'class_ids': array([2]), 'classes': array([b'2'], dtype=object)}
# {'logits': array([-12.933201  , -11.070669  ,   2.7358024 ,   5.757147  ,
#          0.90098405], dtype=float32), 'probabilities': array([7.2278485e-09, 4.6547488e-08, 4.6128642e-02, 9.4650716e-01,
#        7.3640901e-03], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([ 3.8442461,  3.6982849, -0.3161462, -4.6469073, -0.6741298],
#       dtype=float32), 'probabilities': array([5.2884740e-01, 4.5702526e-01, 8.2507795e-03, 1.0855983e-04,
#        5.7679922e-03], dtype=float32), 'class_ids': array([0]), 'classes': array([b'0'], dtype=object)}
# {'logits': array([-2.5220754, -5.5364876,  3.4631062,  6.0184264, -3.583691 ],
#       dtype=float32), 'probabilities': array([1.8126449e-04, 8.8954894e-06, 7.2051659e-02, 9.2769551e-01,
#        6.2698738e-05], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-17.814863  , -16.239756  ,   1.8988769 ,  -0.09775244,
#         19.075329  ], dtype=float32), 'probabilities': array([9.5234429e-17, 4.6010067e-16, 3.4702552e-08, 4.7123438e-09,
#        1.0000000e+00], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-3.9723885 , -4.180008  ,  1.0824269 ,  1.5719419 ,  0.68569684],
#       dtype=float32), 'probabilities': array([0.0019238 , 0.00156312, 0.30160442, 0.49207506, 0.20283367],
#       dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-22.711885 , -15.225991 ,   1.8052986,   2.936422 ,  14.485467 ],
#       dtype=float32), 'probabilities': array([7.0046938e-17, 1.2487402e-13, 3.1121992e-06, 9.6451304e-06,
#        9.9998724e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-1.6667112, -5.411164 , -1.2431514, -4.1451154,  7.2349615],
#       dtype=float32), 'probabilities': array([1.3611218e-04, 3.2188559e-06, 2.0789614e-04, 1.1416669e-05,
#        9.9964130e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-1.0439124 , -7.1730714 ,  0.559204  ,  3.684225  , -0.23164284],
#       dtype=float32), 'probabilities': array([8.2434509e-03, 1.7957644e-05, 4.0957529e-02, 9.3220854e-01,
#        1.8572625e-02], dtype=float32), 'class_ids': array([3]), 'classes': array([b'3'], dtype=object)}
# {'logits': array([-1.2603421, -6.7255044,  1.3286169,  1.0983241,  2.625836 ],
#       dtype=float32), 'probabilities': array([1.3583031e-02, 5.7478690e-05, 1.8087031e-01, 1.4366546e-01,
#        6.6182375e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-20.245825 , -16.7348   ,   1.6875341,   1.8863113,  16.49572  ],
#       dtype=float32), 'probabilities': array([1.1049654e-16, 3.6997065e-15, 3.7058373e-07, 4.5207887e-07,
#        9.9999917e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([-22.826525 , -13.903592 ,   1.3376551,   5.172409 ,  11.58483  ],
#       dtype=float32), 'probabilities': array([1.1339954e-15, 8.5072912e-12, 3.5398174e-05, 1.6382997e-03,
#        9.9832624e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ -1.0749445 , -13.9863405 ,   0.60681385,   4.1196537 ,
#          6.1366663 ], dtype=float32), 'probabilities': array([6.4861611e-04, 1.6019158e-09, 3.4863111e-03, 1.1694268e-01,
#        8.7892234e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}
# {'logits': array([ -0.57627016, -12.473055  ,   0.40959483,   2.5659645 ,
#          5.913304  ], dtype=float32), 'probabilities': array([1.4596867e-03, 9.9437880e-09, 3.9121495e-03, 3.3799849e-02,
#        9.6082836e-01], dtype=float32), 'class_ids': array([4]), 'classes': array([b'4'], dtype=object)}

# %%
df_test.head()
# Out:
#       A_State  Hour  Minute  IsoWeekday
# 212         4     4      15           6
# 1320        2    19      15           7
# 1857        4     9       0           2
# 129         3     7      30           5
# 1030        2    18      45           7
